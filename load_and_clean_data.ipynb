# %% [markdown]
# # Laden und bereinigen der Daten fürs Finetuning der Modelle
# 1. Laden der Linux/Bash Command Datasets
# 2. Laden der SQL Query Datasets
# 3. Bereinigung der Daten
# 4. Upload zu Huggingface

# %% [markdown]
# Laden der benötigten Libraries

# %%
# Für diverse Datenoperationen
import pandas as pd

# Zum Laden von Datasets von Huggingface
from datasets import load_dataset, Dataset as DS
from torch.utils.data import Dataset

import sqlparse
import subprocess

# %% [markdown]
# Erstellen eines Pandas Dataframe, in dem alle Datenpunkte gemeinsam gesammelt werden

# %%
# Erstellen des leeren Dataframes
data = {
    "nl_prompt": [],
    "command": []
}

complete_data_sql = pd.DataFrame(data)
complete_data_bash = complete_data_sql.copy()

# %% [markdown]
# # Linux/Bash Commands

# %% [markdown]
# ### HF [AnishJoshi/nl2bash-custom](https://huggingface.co/datasets/AnishJoshi/nl2bash-custom)
# License=?

# %%
dataset1 = load_dataset("AnishJoshi/nl2bash-custom")
# Out:
# Repo card metadata block was not found. Setting CardData to empty.

# %%
dataset1
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['bash_code', 'nl_command', 'srno'],
#         num_rows: 19658
#     })
#     validation: Dataset({
#         features: ['bash_code', 'nl_command', 'srno'],
#         num_rows: 2457
#     })
#     test: Dataset({
#         features: ['bash_code', 'nl_command', 'srno'],
#         num_rows: 2458
#     })
# })

# %% [markdown]
# Zusammenführung des Train/Validation/Test-Splits des Datensatzes

# %%
train_df1 = pd.DataFrame(dataset1['train'])
validation_df1 = pd.DataFrame(dataset1['validation'])
test_df1 = pd.DataFrame(dataset1['test'])

dataset1_complete = pd.concat([
    train_df1.assign(split='train'),
    validation_df1.assign(split='validation'),
    test_df1.assign(split='test')
])

dataset1_complete
# Out:
#                                               bash_code  \
# 0                              find -mtime +2 -mtime -5
# 1     tempFile="$(mktemp "${TMPDIR:-/tmp/}$(basename...
# 2                            find . -type f -name '* *'
# 3     #!/bin/bash\n\ndir="/path/to/directory"\nfile=...
# 4                             find . -iname foo -type f
# ...                                                 ...
# 2453  #!/bin/bash\n\nmounted_filesystems=$(df -h | g...
# 2454               comm -1 -2 file1.sorted file2.sorted
# 2455    find . -name "filename including space" -print0
# 2456  #!/bin/bash\n\nfor ((i=0; i<6; i++)); do\n    ...
# 2457  find `pwd` -name "file.ext" -exec echo $(dirna...
#
#                                              nl_command   srno  split
# 0     Look for any files that were modified 2-5 days...   3194  train
# 1     Creates temporary file in a TMPDIR folder or /...   8529  train
# 2     Find all files with space in their names under...    240  train
# 3     Create a script to check if a file exists in a...   1433  train
# 4     find regular which case-insensitive name is fo...   2029  train
# ...                                                 ...    ...    ...
# 2453  Create a script to monitor system mounted file...   9052   test
# 2454  Print only common strings in content of files ...   9321   test
# 2455  display all the files having spaces in the cur...   6952   test
# 2456  Monitor system filesystem mount options every ...   2113   test
# 2457  Find all files named "file.ext" in the current...  19982   test
#
# [24573 rows x 4 columns]

# %% [markdown]
# Anhängen des Datensatzes an das Dataframe complete_data

# %%
# übernehmen der erwünschten Spalten
new_rows1 = dataset1_complete[['bash_code', 'nl_command']].copy()

# Umbenennen der übernommenen Spalten
new_rows1.rename(columns={
    'bash_code': 'command',
    'nl_command': 'nl_prompt'
}, inplace=True)

# Anhängen an complete_data
complete_data_bash = pd.concat([complete_data_bash, new_rows1], ignore_index=True)
complete_data_bash
# Out:
#                                                nl_prompt  \
# 0      Look for any files that were modified 2-5 days...
# 1      Creates temporary file in a TMPDIR folder or /...
# 2      Find all files with space in their names under...
# 3      Create a script to check if a file exists in a...
# 4      find regular which case-insensitive name is fo...
# ...                                                  ...
# 24568  Create a script to monitor system mounted file...
# 24569  Print only common strings in content of files ...
# 24570  display all the files having spaces in the cur...
# 24571  Monitor system filesystem mount options every ...
# 24572  Find all files named "file.ext" in the current...
#
#                                                  command
# 0                               find -mtime +2 -mtime -5
# 1      tempFile="$(mktemp "${TMPDIR:-/tmp/}$(basename...
# 2                             find . -type f -name '* *'
# 3      #!/bin/bash\n\ndir="/path/to/directory"\nfile=...
# 4                              find . -iname foo -type f
# ...                                                  ...
# 24568  #!/bin/bash\n\nmounted_filesystems=$(df -h | g...
# 24569               comm -1 -2 file1.sorted file2.sorted
# 24570    find . -name "filename including space" -print0
# 24571  #!/bin/bash\n\nfor ((i=0; i<6; i++)); do\n    ...
# 24572  find `pwd` -name "file.ext" -exec echo $(dirna...
#
# [24573 rows x 2 columns]

# %% [markdown]
# ### HF [Romit2004/LinuxCommands](https://huggingface.co/datasets/Romit2004/LinuxCommands)
# License=MIT
#
# ### Ungenügende Datenqualität! Ignorieren des Datensatzes.

# %%
#dataset2 = load_dataset("Romit2004/LinuxCommands")
#dataset2

# %% [markdown]
# ### HF [bajrangCoder/linux_cmd_alpaca](https://huggingface.co/datasets/bajrangCoder/linux_cmd_alpaca)
# License=MIT
#
# ### Ungenügende Datenqualität! Ignorieren des Datensatzes.

# %%
#dataset3 = load_dataset("bajrangCoder/linux_cmd_alpaca")
#dataset3

# %% [markdown]
# ### HF [aelhalili/bash-commands-dataset](https://huggingface.co/datasets/aelhalili/bash-commands-dataset)
# License=MIT

# %%
dataset4 = load_dataset("aelhalili/bash-commands-dataset")
dataset4
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['prompt', 'response'],
#         num_rows: 840
#     })
# })

# %% [markdown]
# Formattierung des Datensatzes in ein Dataframe

# %%
dataset4_complete = pd.DataFrame(dataset4['train'])
dataset4_complete
# Out:
#                                                 prompt  \
# 0    Move a file called x from the Desktop to the D...
# 1       Open YouTube and search for videos by Mr Beast
# 2    Create a folder named projects inside the Docu...
# 3                             Open the Firefox browser
# 4      Search for all PNG files in the Pictures folder
# ..                                                 ...
# 835                           Start the Apache service
# 836                     Enable Apache to start on boot
# 837                            Stop the Apache service
# 838                         Restart the Apache service
# 839             Check the status of the Apache service
#
#                                               response
# 0                          mv ~/Desktop/x ~/Downloads/
# 1    xdg-open 'https://www.youtube.com/results?sear...
# 2                           mkdir ~/Documents/projects
# 3                                            firefox &
# 4                        find ~/Pictures -name '*.png'
# ..                                                 ...
# 835                       sudo systemctl start apache2
# 836                      sudo systemctl enable apache2
# 837                        sudo systemctl stop apache2
# 838                     sudo systemctl restart apache2
# 839                      sudo systemctl status apache2
#
# [840 rows x 2 columns]

# %% [markdown]
# Anhängen des Datensatzes an das Dataframe complete_data

# %%
# übernehmen der erwünschten Spalten
new_rows4 = dataset4_complete[['prompt', 'response']].copy()

# Umbenennen der übernommenen Spalten
new_rows4.rename(columns={
    'response': 'command',
    'prompt': 'nl_prompt'
}, inplace=True)

# Anhängen an complete_data
complete_data_bash = pd.concat([complete_data_bash, new_rows4], ignore_index=True)
complete_data_bash
# Out:
#                                                nl_prompt  \
# 0      Look for any files that were modified 2-5 days...
# 1      Creates temporary file in a TMPDIR folder or /...
# 2      Find all files with space in their names under...
# 3      Create a script to check if a file exists in a...
# 4      find regular which case-insensitive name is fo...
# ...                                                  ...
# 25408                           Start the Apache service
# 25409                     Enable Apache to start on boot
# 25410                            Stop the Apache service
# 25411                         Restart the Apache service
# 25412             Check the status of the Apache service
#
#                                                  command
# 0                               find -mtime +2 -mtime -5
# 1      tempFile="$(mktemp "${TMPDIR:-/tmp/}$(basename...
# 2                             find . -type f -name '* *'
# 3      #!/bin/bash\n\ndir="/path/to/directory"\nfile=...
# 4                              find . -iname foo -type f
# ...                                                  ...
# 25408                       sudo systemctl start apache2
# 25409                      sudo systemctl enable apache2
# 25410                        sudo systemctl stop apache2
# 25411                     sudo systemctl restart apache2
# 25412                      sudo systemctl status apache2
#
# [25413 rows x 2 columns]

# %% [markdown]
# ### Kaggle [Kushagragoyal060705/Complex-Linux-commands-from-natual-language](https://www.kaggle.com/datasets/kushagragoyal060705/complex-linux-commands-from-natual-language)
# License=Apache 2.0

# %%
dataset5 = load_dataset("terminAl-thesis-2025/big_bash")
dataset5
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'output'],
#         num_rows: 1000000
#     })
# })

# %%
dataset5 = pd.DataFrame(dataset5['train'])
dataset5
# Out:
#                                                     input  \
# 0              Find all files modified in the last 7 days
# 1       Recursively change ownership of a directory to...
# 2              List open files by a process with PID 1234
# 3               Monitor system resource usage dynamically
# 4               Copy all .log files to a backup directory
# ...                                                   ...
# 999995                          List all running services
# 999996  Find and replace 'foo' with 'bar' in all .txt ...
# 999997                       Check if port 8080 is in use
# 999998                   Display real-time disk I/O stats
# 999999         Create a compressed archive of a directory
#
#                                             output
# 0                         find . -type f -mtime -7
# 1            chown -R john:john /path/to/directory
# 2                                     lsof -p 1234
# 3                                     dstat -cdngy
# 4                        cp *.log /path/to/backup/
# ...                                            ...
# 999995         systemctl list-units --type=service
# 999996                  sed -i 's/foo/bar/g' *.txt
# 999997                  netstat -tulnp | grep 8080
# 999998                                iostat -dx 1
# 999999  tar -czvf backup.tar.gz /path/to/directory
#
# [1000000 rows x 2 columns]

# %% [markdown]
# Anhängen des Datensatzes an das Dataframe complete_data

# %%
# übernehmen der erwünschten Spalten
new_rows5 = dataset5[['input', 'output']].copy()

# Umbenennen der übernommenen Spalten
new_rows5.rename(columns={
    'output': 'command',
    'input': 'nl_prompt'
}, inplace=True)

# Anhängen an complete_data
complete_data_bash = pd.concat([complete_data_bash, new_rows5], ignore_index=True)
complete_data_bash
# Out:
#                                                  nl_prompt  \
# 0        Look for any files that were modified 2-5 days...
# 1        Creates temporary file in a TMPDIR folder or /...
# 2        Find all files with space in their names under...
# 3        Create a script to check if a file exists in a...
# 4        find regular which case-insensitive name is fo...
# ...                                                    ...
# 1025408                          List all running services
# 1025409  Find and replace 'foo' with 'bar' in all .txt ...
# 1025410                       Check if port 8080 is in use
# 1025411                   Display real-time disk I/O stats
# 1025412         Create a compressed archive of a directory
#
#                                                    command
# 0                                 find -mtime +2 -mtime -5
# 1        tempFile="$(mktemp "${TMPDIR:-/tmp/}$(basename...
# 2                               find . -type f -name '* *'
# 3        #!/bin/bash\n\ndir="/path/to/directory"\nfile=...
# 4                                find . -iname foo -type f
# ...                                                    ...
# 1025408                systemctl list-units --type=service
# 1025409                         sed -i 's/foo/bar/g' *.txt
# 1025410                         netstat -tulnp | grep 8080
# 1025411                                       iostat -dx 1
# 1025412         tar -czvf backup.tar.gz /path/to/directory
#
# [1025413 rows x 2 columns]

# %% [markdown]
# # SQL Queries/Commands

# %% [markdown]
# ### HF [zerolink/zsql-postgres-dpo](https://huggingface.co/datasets/zerolink/zsql-postgres-dpo)
# ### License=(Multiple Licenses and also "viral" Creative Commons Licenses)! <--  Ignorieren des Datensatzes.

# %%
#dataset6 = load_dataset("zerolink/zsql-postgres-dpo")
#dataset6

# %% [markdown]
# ### HF [omeryentur/text-to-postgresql](https://huggingface.co/datasets/omeryentur/text-to-postgresql)
# License=?

# %%
dataset7 = load_dataset("omeryentur/text-to-postgresql")
dataset7
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'query', 'schema', '__index_level_0__'],
#         num_rows: 58696
#     })
# })

# %% [markdown]
# Formattierung des Datensatzes in ein Dataframe

# %%
dataset7_complete = pd.DataFrame(dataset7['train'])
dataset7_complete
# Out:
#                                                 question  \
# 0      What is the total number of addresses for each...
# 1      Find all addresses in the United States that d...
# 2      What is the count of addresses in Europe by ci...
# 3      Get a list of all countries, along with the nu...
# 4      What is the total number of addresses for each...
# ...                                                  ...
# 58691  What are the languages spoken in the country o...
# 58692  What is the city with the highest GDP in the S...
# 58693  What is the average population of cities in th...
# 58694  Which country has the highest GDP among countr...
# 58695  What are the total number of matches played by...
#
#                                                    query  \
# 0      SELECT country, state_province_county, COUNT(*...
# 1      SELECT * FROM addresses WHERE country = 'Unite...
# 2      SELECT city, COUNT(*) AS address_count FROM ad...
# 3      SELECT country, COUNT(*) AS address_count FROM...
# 4      SELECT city, COUNT(*) AS total_addresses FROM ...
# ...                                                  ...
# 58691  SELECT language FROM countrylanguage WHERE cou...
# 58692  SELECT city, gdp FROM city WHERE hanzi LIKE 'S...
# 58693  SELECT AVG(regional_population) FROM city WHER...
# 58694  SELECT country_name, SUM(gdp) AS total_gdp FRO...
# 58695  SELECT p.first_name, p.last_name, COUNT(*) AS ...
#
#                                                   schema  __index_level_0__
# 0      \nCREATE TABLE addresses (\n\taddress_id INTEG...                  0
# 1      \nCREATE TABLE addresses (\n\taddress_id INTEG...                  1
# 2      \nCREATE TABLE addresses (\n\taddress_id INTEG...                  2
# 3      \nCREATE TABLE addresses (\n\taddress_id INTEG...                  3
# 4      \nCREATE TABLE addresses (\n\taddress_id INTEG...                  4
# ...                                                  ...                ...
# 58691  \nCREATE TABLE city (\n\tcity_id INTEGER, \n\t...              71962
# 58692  \nCREATE TABLE city (\n\tcity_id INTEGER, \n\t...              71963
# 58693  \nCREATE TABLE city (\n\tcity_id INTEGER, \n\t...              71965
# 58694  \nCREATE TABLE city (\n\tcity_id INTEGER, \n\t...              71966
# 58695  \nCREATE TABLE matches (\n\tbest_of INTEGER, \...              71967
#
# [58696 rows x 4 columns]

# %% [markdown]
# Anhängen des Datensatzes an das Dataframe complete_data

# %%
# übernehmen der erwünschten Spalten
new_rows7 = dataset7_complete[['question', 'query']].copy()

# Umbenennen der übernommenen Spalten
new_rows7.rename(columns={
    'query': 'command',
    'question': 'nl_prompt'
}, inplace=True)

# Anhängen an complete_data
complete_data_sql = pd.concat([complete_data_sql, new_rows7], ignore_index=True)
complete_data_sql
# Out:
#                                                nl_prompt  \
# 0      What is the total number of addresses for each...
# 1      Find all addresses in the United States that d...
# 2      What is the count of addresses in Europe by ci...
# 3      Get a list of all countries, along with the nu...
# 4      What is the total number of addresses for each...
# ...                                                  ...
# 58691  What are the languages spoken in the country o...
# 58692  What is the city with the highest GDP in the S...
# 58693  What is the average population of cities in th...
# 58694  Which country has the highest GDP among countr...
# 58695  What are the total number of matches played by...
#
#                                                  command
# 0      SELECT country, state_province_county, COUNT(*...
# 1      SELECT * FROM addresses WHERE country = 'Unite...
# 2      SELECT city, COUNT(*) AS address_count FROM ad...
# 3      SELECT country, COUNT(*) AS address_count FROM...
# 4      SELECT city, COUNT(*) AS total_addresses FROM ...
# ...                                                  ...
# 58691  SELECT language FROM countrylanguage WHERE cou...
# 58692  SELECT city, gdp FROM city WHERE hanzi LIKE 'S...
# 58693  SELECT AVG(regional_population) FROM city WHER...
# 58694  SELECT country_name, SUM(gdp) AS total_gdp FRO...
# 58695  SELECT p.first_name, p.last_name, COUNT(*) AS ...
#
# [58696 rows x 2 columns]

# %%
new_rows7
# Out:
#                                                nl_prompt  \
# 0      What is the total number of addresses for each...
# 1      Find all addresses in the United States that d...
# 2      What is the count of addresses in Europe by ci...
# 3      Get a list of all countries, along with the nu...
# 4      What is the total number of addresses for each...
# ...                                                  ...
# 58691  What are the languages spoken in the country o...
# 58692  What is the city with the highest GDP in the S...
# 58693  What is the average population of cities in th...
# 58694  Which country has the highest GDP among countr...
# 58695  What are the total number of matches played by...
#
#                                                  command
# 0      SELECT country, state_province_county, COUNT(*...
# 1      SELECT * FROM addresses WHERE country = 'Unite...
# 2      SELECT city, COUNT(*) AS address_count FROM ad...
# 3      SELECT country, COUNT(*) AS address_count FROM...
# 4      SELECT city, COUNT(*) AS total_addresses FROM ...
# ...                                                  ...
# 58691  SELECT language FROM countrylanguage WHERE cou...
# 58692  SELECT city, gdp FROM city WHERE hanzi LIKE 'S...
# 58693  SELECT AVG(regional_population) FROM city WHER...
# 58694  SELECT country_name, SUM(gdp) AS total_gdp FRO...
# 58695  SELECT p.first_name, p.last_name, COUNT(*) AS ...
#
# [58696 rows x 2 columns]

# %% [markdown]
# ### HF [gretelai/synthetic_text_to_sql](https://huggingface.co/datasets/gretelai/synthetic_text_to_sql)
# License=Apache-2.0

# %%
dataset8 = load_dataset("gretelai/synthetic_text_to_sql")
dataset8
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'domain', 'domain_description', 'sql_complexity', 'sql_complexity_description', 'sql_task_type', 'sql_task_type_description', 'sql_prompt', 'sql_context', 'sql', 'sql_explanation'],
#         num_rows: 100000
#     })
#     test: Dataset({
#         features: ['id', 'domain', 'domain_description', 'sql_complexity', 'sql_complexity_description', 'sql_task_type', 'sql_task_type_description', 'sql_prompt', 'sql_context', 'sql', 'sql_explanation'],
#         num_rows: 5851
#     })
# })

# %% [markdown]
# Zusammenführung des Train/Test-Splits des Datensatzes

# %%
train_df8 = pd.DataFrame(dataset8['train'])
test_df8 = pd.DataFrame(dataset8['test'])

dataset8_complete = pd.concat([
    train_df8.assign(split='train'),
    test_df8.assign(split='test')
])

dataset8_complete
# Out:
#         id              domain  \
# 0     5097            forestry
# 1     5098    defense industry
# 2     5099      marine biology
# 3     5100  financial services
# 4     5101              energy
# ...    ...                 ...
# 5846  5847             museums
# 5847  5848    waste management
# 5848  5849     water resources
# 5849  5850    fitness industry
# 5850  5851    fitness industry
#
#                                      domain_description    sql_complexity  \
# 0     Comprehensive data on sustainable forest manag...       single join
# 1     Defense contract data, military equipment main...       aggregation
# 2     Comprehensive data on marine species, oceanogr...         basic SQL
# 3     Detailed financial data including investment s...       aggregation
# 4     Energy market data covering renewable energy s...  window functions
# ...                                                 ...               ...
# 5846  Visitor demographics, exhibition analytics, co...         basic SQL
# 5847  Waste generation metrics, recycling rates, lan...         basic SQL
# 5848  Water usage metrics, drought impact assessment...       aggregation
# 5849  Workout data, membership demographics, wearabl...       aggregation
# 5850  Workout data, membership demographics, wearabl...        subqueries
#
#                              sql_complexity_description  \
# 0           only one join (specify inner, outer, cross)
# 1     aggregation functions (COUNT, SUM, AVG, MIN, M...
# 2              basic SQL with a simple select statement
# 3     aggregation functions (COUNT, SUM, AVG, MIN, M...
# 4     window functions (e.g., ROW_NUMBER, LEAD, LAG,...
# ...                                                 ...
# 5846           basic SQL with a simple select statement
# 5847           basic SQL with a simple select statement
# 5848  aggregation functions (COUNT, SUM, AVG, MIN, M...
# 5849  aggregation functions (COUNT, SUM, AVG, MIN, M...
# 5850  subqueries, including correlated and nested su...
#
#                 sql_task_type  \
# 0     analytics and reporting
# 1     analytics and reporting
# 2     analytics and reporting
# 3     analytics and reporting
# 4     analytics and reporting
# ...                       ...
# 5846  analytics and reporting
# 5847  analytics and reporting
# 5848  analytics and reporting
# 5849  analytics and reporting
# 5850  analytics and reporting
#
#                               sql_task_type_description  \
# 0     generating reports, dashboards, and analytical...
# 1     generating reports, dashboards, and analytical...
# 2     generating reports, dashboards, and analytical...
# 3     generating reports, dashboards, and analytical...
# 4     generating reports, dashboards, and analytical...
# ...                                                 ...
# 5846  generating reports, dashboards, and analytical...
# 5847  generating reports, dashboards, and analytical...
# 5848  generating reports, dashboards, and analytical...
# 5849  generating reports, dashboards, and analytical...
# 5850  generating reports, dashboards, and analytical...
#
#                                              sql_prompt  \
# 0     What is the total volume of timber sold by eac...
# 1     List all the unique equipment types and their ...
# 2     How many marine species are found in the South...
# 3     What is the total trade value and average pric...
# 4     Find the energy efficiency upgrades with the h...
# ...                                                 ...
# 5846  How many visitors are from the city of "Seattl...
# 5847  What is the total waste generation in kilogram...
# 5848  What is the maximum wastewater volume treated ...
# 5849  Calculate the total workout duration and numbe...
# 5850  How many users have a higher heart rate on wee...
#
#                                             sql_context  \
# 0     CREATE TABLE salesperson (salesperson_id INT, ...
# 1     CREATE TABLE equipment_maintenance (equipment_...
# 2     CREATE TABLE marine_species (name VARCHAR(50),...
# 3     CREATE TABLE trade_history (id INT, trader_id ...
# 4     CREATE TABLE upgrades (id INT, cost FLOAT, typ...
# ...                                                 ...
# 5846  CREATE TABLE visitor (visitor_id INT, visitor_...
# 5847  CREATE TABLE organizations (id INT, name TEXT,...
# 5848  CREATE TABLE WasteWaterTreatment (Id INT PRIMA...
# 5849  CREATE TABLE Workouts (user_id INT, workout_da...
# 5850  CREATE TABLE heart_rates (id INT, user_id INT,...
#
#                                                     sql  \
# 0     SELECT salesperson_id, name, SUM(volume) as to...
# 1     SELECT equipment_type, SUM(maintenance_frequen...
# 2     SELECT COUNT(*) FROM marine_species WHERE loca...
# 3     SELECT trader_id, stock, SUM(price * quantity)...
# 4     SELECT type, cost FROM (SELECT type, cost, ROW...
# ...                                                 ...
# 5846  SELECT COUNT(*) FROM visitor WHERE visitor_cit...
# 5847  SELECT SUM(annual_waste_generation_kg) FROM or...
# 5848  SELECT Plant, MAX(Volume) FROM WasteWaterTreat...
# 5849  SELECT user_id, SUM(workout_duration) as total...
# 5850  SELECT COUNT(*) FROM (SELECT user_id, CASE WHE...
#
#                                         sql_explanation  split
# 0     Joins timber_sales and salesperson tables, gro...  train
# 1     This query groups the equipment_maintenance ta...  train
# 2     This query counts the number of marine species...  train
# 3     This query calculates the total trade value an...  train
# 4     The SQL query uses the ROW_NUMBER function to ...  train
# ...                                                 ...    ...
# 5846  This SQL query counts all the rows in the "vis...   test
# 5847  This query calculates the total waste generati...   test
# 5848  This SQL query calculates the maximum wastewat...   test
# 5849  The query filters the data to include only wor...   test
# 5850  The subquery separates heart rates based on da...   test
#
# [105851 rows x 12 columns]

# %% [markdown]
# Anhängen des Datensatzes an das Dataframe complete_data

# %%
# übernehmen der erwünschten Spalten
new_rows8 = dataset8_complete[['sql_prompt', 'sql']].copy()

# Umbenennen der übernommenen Spalten
new_rows8.rename(columns={
    'sql': 'command',
    'sql_prompt': 'nl_prompt'
}, inplace=True)

# Anhängen an complete_data
complete_data_sql = pd.concat([complete_data_sql, new_rows8], ignore_index=True)
complete_data_sql
# Out:
#                                                 nl_prompt  \
# 0       What is the total number of addresses for each...
# 1       Find all addresses in the United States that d...
# 2       What is the count of addresses in Europe by ci...
# 3       Get a list of all countries, along with the nu...
# 4       What is the total number of addresses for each...
# ...                                                   ...
# 164542  How many visitors are from the city of "Seattl...
# 164543  What is the total waste generation in kilogram...
# 164544  What is the maximum wastewater volume treated ...
# 164545  Calculate the total workout duration and numbe...
# 164546  How many users have a higher heart rate on wee...
#
#                                                   command
# 0       SELECT country, state_province_county, COUNT(*...
# 1       SELECT * FROM addresses WHERE country = 'Unite...
# 2       SELECT city, COUNT(*) AS address_count FROM ad...
# 3       SELECT country, COUNT(*) AS address_count FROM...
# 4       SELECT city, COUNT(*) AS total_addresses FROM ...
# ...                                                   ...
# 164542  SELECT COUNT(*) FROM visitor WHERE visitor_cit...
# 164543  SELECT SUM(annual_waste_generation_kg) FROM or...
# 164544  SELECT Plant, MAX(Volume) FROM WasteWaterTreat...
# 164545  SELECT user_id, SUM(workout_duration) as total...
# 164546  SELECT COUNT(*) FROM (SELECT user_id, CASE WHE...
#
# [164547 rows x 2 columns]

# %% [markdown]
# # Bereinigung der Daten

# %% [markdown]
# Entferne Duplikate und Prüfe SQL-Commands auf Validität

# %%
# Filtere nach eindeutigen Werten
unique_sql_nl_prompts = complete_data_sql["nl_prompt"].unique()
unique_sql_commands = complete_data_sql["command"].unique()

print(f"Length of original DataFrame: {len(complete_data_sql)}")
print(f"Unique NL Prompts: {len(unique_sql_nl_prompts)}")
print(f"Unique Commands: {len(unique_sql_commands)}")

# Entferne doppelte oder mehrfache Prompts (da mehr Commands als Prompts, ansonsten doppelte Commands entfernen)
complete_data_sql = complete_data_sql.drop_duplicates(subset="nl_prompt", keep="first").copy()
print(f"Length of complete data: {len(complete_data_sql)}")
print(f"Unique Commands: {len(complete_data_sql['command'].unique())}")
print(f"Verbleibende doppelte Einträge: {len(complete_data_sql)-len(complete_data_sql['command'].unique())}")

def is_valid_sql(command: str) -> bool:
    try:
        parsed = sqlparse.parse(command)
        return bool(parsed) and all(stmt.tokens for stmt in parsed)
    except Exception:
        return False

# Apply syntax check to each row
complete_data_sql["check"] = complete_data_sql["command"].apply(is_valid_sql)
# Out:
# Length of original DataFrame: 164547
# Unique NL Prompts: 161477
# Unique Commands: 163733
# Length of complete data: 161477
# Unique Commands: 160674
# Verbleibende doppelte Einträge: 803

# %% [markdown]
# Prüfe Bash-Commands auf Validität
#
# **Vorsicht! Sicherheitshalber diesen Befehl in einer gesicherten Umgebung (Docker oder VM) ausführen**

# %%
# Filtere nach eindeutigen Werten
unique_bash_nl_prompts = complete_data_bash["nl_prompt"].unique()
unique_bash_commands = complete_data_bash["command"].unique()

print(f"Length of original DataFrame: {len(complete_data_bash)}")
print(f"Unique NL Prompts: {len(unique_bash_nl_prompts)}")
print(f"Unique Commands: {len(unique_bash_commands)}")

# Entferne doppelte oder mehrfache Prompts (da mehr Commands als Prompts, ansonsten doppelte Commands entfernen)
complete_data_bash = complete_data_bash.drop_duplicates(subset="nl_prompt", keep="first").copy()
print(f"Length of complete data: {len(complete_data_bash)}")
print(f"Unique Commands: {len(complete_data_bash['command'].unique())}")
print(f"Verbleibende doppelte Einträge: {len(complete_data_bash)-len(complete_data_bash['command'].unique())}")

def is_valid_bash_syntax(command: str) -> bool:
    try:
        result = subprocess.run(
            ['bash', '-n'],
            input=command.encode('utf-8'),
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            timeout=2,
            check=False
        )
        return result.returncode == 0
    except Exception:
        return False

complete_data_bash["check"] = complete_data_bash["command"].apply(is_valid_bash_syntax)
# Out:
# Length of original DataFrame: 1025413
# Unique NL Prompts: 13690
# Unique Commands: 13152
# Length of complete data: 13690
# Unique Commands: 11335
# Verbleibende doppelte Einträge: 2355

# %% [markdown]
# Zusammenführen der Dataframes

# %%
complete_data = pd.concat([complete_data_sql, complete_data_bash])

# %% [markdown]
# Prüfe auf falsche Syntax und entferne diese

# %%
false_count = (complete_data['check'] == False).sum()
print(f"Einträge mit falscher Syntax zu entfernen: {false_count}")

# Remove rows where column 'A' is False
complete_data = complete_data[complete_data['check']]
# Out:
# Einträge mit falscher Syntax zu entfernen: 188

# %%
complete_data
# Out:
#                                                nl_prompt  \
# 0      What is the total number of addresses for each...
# 1      Find all addresses in the United States that d...
# 2      What is the count of addresses in Europe by ci...
# 3      Get a list of all countries, along with the nu...
# 4      What is the total number of addresses for each...
# ...                                                  ...
# 25418                          List all running services
# 25419  Find and replace 'foo' with 'bar' in all .txt ...
# 25420                       Check if port 8080 is in use
# 25421                   Display real-time disk I/O stats
# 25422         Create a compressed archive of a directory
#
#                                                  command  check
# 0      SELECT country, state_province_county, COUNT(*...   True
# 1      SELECT * FROM addresses WHERE country = 'Unite...   True
# 2      SELECT city, COUNT(*) AS address_count FROM ad...   True
# 3      SELECT country, COUNT(*) AS address_count FROM...   True
# 4      SELECT city, COUNT(*) AS total_addresses FROM ...   True
# ...                                                  ...    ...
# 25418                systemctl list-units --type=service   True
# 25419                         sed -i 's/foo/bar/g' *.txt   True
# 25420                         netstat -tulnp | grep 8080   True
# 25421                                       iostat -dx 1   True
# 25422         tar -czvf backup.tar.gz /path/to/directory   True
#
# [174979 rows x 3 columns]

# %% [markdown]
#  # Upload zu Huggingface

# %%
hf_complete_data = DS.from_pandas(complete_data)
hf_complete_data.push_to_hub("terminAl-thesis-2025/combined_dataset")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/175 [00:00<?, ?ba/s]
# No files have been modified since last commit. Skipping to prevent empty commit.
# CommitInfo(commit_url='https://huggingface.co/datasets/terminAl-thesis-2025/combined_dataset/commit/7e8e7f0199037e8c9852db3c71e30c02d123983c', commit_message='Upload dataset', commit_description='', oid='7e8e7f0199037e8c9852db3c71e30c02d123983c', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/terminAl-thesis-2025/combined_dataset', endpoint='https://huggingface.co', repo_type='dataset', repo_id='terminAl-thesis-2025/combined_dataset'), pr_revision=None, pr_num=None)
