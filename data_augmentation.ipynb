# %% [markdown]
# # _____________________
# #          Achtung bei "Run All"
# # _____________________

# %% [markdown]
# # Erstellen des Batch-Sets

# %%
# Für diverse Datenoperationen
import pandas as pd
from accelerate.commands.config.update import description

# Zum Laden von Datasets von Huggingface
from datasets import load_dataset, Dataset as DS

import requests as r

import json

from tqdm import tqdm

# %% [markdown]
# Laden des Datasets

# %%
dataset = load_dataset("terminAl-thesis-2025/combined_dataset")
dataset_df = pd.DataFrame(dataset["train"])

dataset_df
# Out:
#                                                 nl_prompt  \
# 0       What is the total number of addresses for each...
# 1       Find all addresses in the United States that d...
# 2       What is the count of addresses in Europe by ci...
# 3       Get a list of all countries, along with the nu...
# 4       What is the total number of addresses for each...
# ...                                                   ...
# 174974                          List all running services
# 174975  Find and replace 'foo' with 'bar' in all .txt ...
# 174976                       Check if port 8080 is in use
# 174977                   Display real-time disk I/O stats
# 174978         Create a compressed archive of a directory
#
#                                                   command  check  \
# 0       SELECT country, state_province_county, COUNT(*...   True
# 1       SELECT * FROM addresses WHERE country = 'Unite...   True
# 2       SELECT city, COUNT(*) AS address_count FROM ad...   True
# 3       SELECT country, COUNT(*) AS address_count FROM...   True
# 4       SELECT city, COUNT(*) AS total_addresses FROM ...   True
# ...                                                   ...    ...
# 174974                systemctl list-units --type=service   True
# 174975                         sed -i 's/foo/bar/g' *.txt   True
# 174976                         netstat -tulnp | grep 8080   True
# 174977                                       iostat -dx 1   True
# 174978         tar -czvf backup.tar.gz /path/to/directory   True
#
#         __index_level_0__
# 0                       0
# 1                       1
# 2                       2
# 3                       3
# 4                       4
# ...                   ...
# 174974              25418
# 174975              25419
# 174976              25420
# 174977              25421
# 174978              25422
#
# [174979 rows x 4 columns]

# %% [markdown]
# Hinzufügen einer eindeutigen ID (sequenzielle ID)

# %%
dataset_df["id"] = (dataset_df.index +1).astype(str)
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/175 [00:00<?, ?ba/s]
# No files have been modified since last commit. Skipping to prevent empty commit.
# CommitInfo(commit_url='https://huggingface.co/datasets/terminAl-thesis-2025/trainings_set/commit/1498b7701aab0b5c06051ee383ecab6c16957a97', commit_message='Upload dataset', commit_description='', oid='1498b7701aab0b5c06051ee383ecab6c16957a97', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/terminAl-thesis-2025/trainings_set', endpoint='https://huggingface.co', repo_type='dataset', repo_id='terminAl-thesis-2025/trainings_set'), pr_revision=None, pr_num=None)

# %%
dataset_df.head(2)
# Out:
#                                            nl_prompt  \
# 0  What is the total number of addresses for each...
# 1  Find all addresses in the United States that d...
#
#                                              command  check  \
# 0  SELECT country, state_province_county, COUNT(*...   True
# 1  SELECT * FROM addresses WHERE country = 'Unite...   True
#
#    __index_level_0__ id
# 0                  0  1
# 1                  1  2

# %% [markdown]
# Definition des Systemprompts

# %%
base_prompt = '''Du bist ein spezialisierter Assistent, der natürlichsprachliche Anfragen zu CLI-Befehlen (Command Line Interface) oder SQL-Abfragen in ein strukturiertes JSON-Format übersetzt. Deine Antwort muss immer exakt im folgenden JSON-Format sein:

{{
 "command": "der vollständige und korrekte Befehl/die SQL-Abfrage",
 "tool": "bash/sql",
 "risk_level": "low/medium/high",
 "description": "Kurze Beschreibung des Befehls oder der Abfrage",
 "detailed_description": "Längere Erklärung, was der Befehl tut und wie die Parameter funktionieren",
 "potential_consequences": ["mögliche Auswirkungen oder Risiken des Befehls", "weitere Auswirkung wenn zutreffend"]
}}

Konvertiere die folgende natürlichsprachliche Anfrage in das JSON-Format. Verwende dabei ausschließlich die Informationen aus der Anfrage und dem zugehörigen Befehl:

ANFRAGE: "{0}"
BEFEHL: "{1}"

Richtlinien:
1. Bestimme den Wert für "tool" korrekt basierend auf dem Befehl: Verwende "sql" für SQL-Abfragen und "bash" für Linux/Bash-Befehle.
2. Achte unbedingt auf die korrekte Syntax des Commands. Korrigiere den Command falls nötig (z.B. fehlendes Semikolon bei SQL-Abfragen hinzufügen).
3. Gib für SQL-Abfragen "low" als risk_level an, es sei denn, es handelt sich um DELETE, DROP, ALTER oder UPDATE-Operationen.
4. Für CLI-Befehle bewerte das Risiko basierend auf der Möglichkeit von Datenverlust oder Systemänderungen.
5. Die "description" sollte prägnant sein (max. 1 Satz).
6. Die "detailed_description" sollte nicht mehr als drei Sätze umfassen.
7. Liste unter "potential_consequences" alle relevanten möglichen Auswirkungen auf, oder ein leeres Array [], wenn keine nennenswerten Risiken bestehen.
8. Antworte IMMER mit einem gültigen JSON-Objekt, ohne Einleitung oder Abschluss.
9. Verwende keine Formatierungszeichen wie "\\n", "\\t" oder andere Escape-Sequenzen im JSON.
10. Stelle sicher, dass das JSON vollständig gültig ist und direkt als Python-Dictionary geladen werden kann.
11. Halte dich strikt an doppelte Anführungszeichen für Keys und String-Werte, wie es im JSON-Standard vorgeschrieben ist.
12. Gib "description", "detailed_description" und "potential_consequences" IMMER in deutscher Sprache zurück, auch wenn die ursprüngliche Anfrage auf Englisch ist.
13. Verwende bei der Übersetzung eine klare und präzise deutsche Fachsprache.

Ergänzende Richtlinien zur Bestimmung des "risk_level":

- Verwende "low", wenn der Befehl:
  * rein lesend ist (z.B. `ls`, `cat`, `SELECT` ohne `JOIN` auf große Tabellen),
  * keine Änderungen an Daten, Systemkonfigurationen oder Dateistrukturen vornimmt,
  * typischerweise keine Auswirkungen auf andere Prozesse oder Nutzer hat.

- Verwende "medium", wenn der Befehl:
  * potenziell Änderungen an Dateien, Datenbankeinträgen oder Konfigurationen durchführt, jedoch reversibel oder mit geringer Auswirkung ist (z.B. `mv`, `cp`, `touch`, `UPDATE` mit WHERE),
  * Netzwerkverbindungen aufbaut oder Systemprozesse anstößt (z.B. `curl`, `ping`, `systemctl restart`),
  * selektive Datenbearbeitung in SQL betrifft, jedoch nicht strukturverändernd ist.

- Verwende "high", wenn der Befehl:
  * irreversible Änderungen am System oder an Daten verursacht (z.B. `rm -rf /`, `DROP TABLE`, `ALTER DATABASE`),
  * kritische Dienste beeinträchtigt oder beendet (z.B. `kill -9 1`, `shutdown`),
  * ohne weitere Rückfrage systemweite Auswirkungen haben kann,
  * Sicherheitsrisiken birgt, z.B. durch Datenfreigabe, Prozessbeeinflussung oder das Löschen von Benutzerkonten.

Beziehe immer auch Kontext und typische Folgen mit ein. Wenn Unsicherheit besteht, ist ein konservativerer (höherer) Risikowert zu bevorzugen.'''

# %% [markdown]
# Erweitere Dataframe

# %%
dataset_df["json"] = ""

# %%
dataset_df.columns
# Out:
# Index(['nl_prompt', 'command', 'check', '__index_level_0__', 'id', 'json'], dtype='object')

# %% [markdown]
# Erstellen der Requests, mit Testsplit (um die API zu testen und Kosten abzuschätzen)

# %%
test_requests = {}
test_requests_mini = {}
requests = {"batch_1":{}}
model = "llama3.1:8b-instruct-q5_K_M"
#model = "llama3.3:70b-instruct-q4_K_M"
batch_size = 1000
batch = 1

for index, row in dataset_df.iterrows():
    nl_prompt = row['nl_prompt']
    command = row['command']
    prompt = base_prompt.format(nl_prompt, command)
    request = {
        "model": model,
        "prompt": prompt,
        "format": "json",
        "stream": False
    }

    if index < batch_size:
        batch_id = "batch_{}".format(batch)
        requests[batch_id][index] = request
    elif index == batch_size:
        batch += 1
        batch_size += 1000
        batch_id = "batch_{}".format(batch)
        requests[batch_id] = {}
        requests[batch_id][index] = request

print(len(test_requests))
print(len(requests))
# Out:
# 0
# 175

# %%
requests["batch_1"]
# Out:
# {0: {'model': 'llama3.1:8b-instruct-q5_K_M',
#   'prompt': 'Du bist ein spezialisierter Assistent, der natürlichsprachliche Anfragen zu CLI-Befehlen (Command Line Interface) oder SQL-Abfragen in ein strukturiertes JSON-Format übersetzt. Deine Antwort muss immer exakt im folgenden JSON-Format sein:\n\n{\n "command": "der vollständige und korrekte Befehl/die SQL-Abfrage",\n "tool": "bash/sql",\n "risk_level": "low/medium/high",\n "description": "Kurze Beschreibung des Befehls oder der Abfrage",\n "detailed_description": "Längere Erklärung, was der Befehl tut und wie die Parameter funktionieren",\n "potential_consequences": ["mögliche Auswirkungen oder Risiken des Befehls", "weitere Auswirkung wenn zutreffend"]\n}\n\nKonvertiere die folgende natürlichsprachliche Anfrage in das JSON-Format. Verwende dabei ausschließlich die Informationen aus der Anfrage und dem zugehörigen Befehl:\n\nANFRAGE: "What is the total number of addresses for each country, grouped by state/province/county?"\nBEFEHL: "SELECT country, state_province_county, COUNT(*) AS total_addresses FROM addresses GROUP BY country, state_province_county;"\n\nRichtlinien:\n1. Bestimme den Wert für "tool" korrekt basierend auf dem Befehl: Verwende "sql" für SQL-Abfragen und "bash" für Linux/Bash-Befehle.\n2. Achte unbedingt auf die korrekte Syntax des Commands. Korrigiere den Command falls nötig (z.B. fehlendes Semikolon bei SQL-Abfragen hinzufügen).\n3. Gib für SQL-Abfragen "low" als risk_level an, es sei denn, es handelt sich um DELETE, DROP, ALTER oder UPDATE-Operationen.\n4. Für CLI-Befehle bewerte das Risiko basierend auf der Möglichkeit von Datenverlust oder Systemänderungen.\n5. Die "description" sollte prägnant sein (max. 1 Satz).\n6. Die "detailed_description" sollte nicht mehr als drei Sätze umfassen.\n7. Liste unter "potential_consequences" alle relevanten möglichen Auswirkungen auf, oder ein leeres Array [], wenn keine nennenswerten Risiken bestehen.\n8. Antworte IMMER mit einem gültigen JSON-Objekt, ohne Einleitung oder Abschluss.\n9. Verwende keine Formatierungszeichen wie "\\n", "\\t" oder andere Escape-Sequenzen im JSON.\n10. Stelle sicher, dass das JSON vollständig gültig ist und direkt als Python-Dictionary geladen werden kann.\n11. Halte dich strikt an doppelte Anführungszeichen für Keys und String-Werte, wie es im JSON-Standard vorgeschrieben ist.\n12. Gib "description", "detailed_description" und "potential_consequences" IMMER in deutscher Sprache zurück, auch wenn die ursprüngliche Anfrage auf Englisch ist.\n13. Verwende bei der Übersetzung eine klare und präzise deutsche Fachsprache.\n\nErgänzende Richtlinien zur Bestimmung des "risk_level":\n\n- Verwende "low", wenn der Befehl:\n  * rein lesend ist (z.B. `ls`, `cat`, `SELECT` ohne `JOIN` auf große Tabellen),\n  * keine Änderungen an Daten, Systemkonfigurationen oder Dateistrukturen vornimmt,\n  * typischerweise keine Auswirkungen auf andere Prozesse oder Nutzer hat.\n\n- Verwende "medium", wenn der Befehl:\n  * potenziell Änderungen an Dateien, Datenbankeinträgen oder Konfigurationen durchführt, jedoch reversibel oder mit geringer Auswirkung ist (z.B. `mv`, `cp`, `touch`, `UPDATE` mit WHERE),\n  * Netzwerkverbindungen aufbaut oder Systemprozesse anstößt (z.B. `curl`, `ping`, `systemctl restart`),\n  * selektive Datenbearbeitung in SQL betrifft, jedoch nicht strukturverändernd ist.\n\n- Verwende "high", wenn der Befehl:\n  * irreversible Änderungen am System oder an Daten verursacht (z.B. `rm -rf /`, `DROP TABLE`, `ALTER DATABASE`),\n  * kritische Dienste beeinträchtigt oder beendet (z.B. `kill -9 1`, `shutdown`),\n  * ohne weitere Rückfrage systemweite Auswirkungen haben kann,\n  * Sicherheitsrisiken birgt, z.B. durch Datenfreigabe, Prozessbeeinflussung oder das Löschen von Benutzerkonten.\n\nBeziehe immer auch Kontext und typische Folgen mit ein. Wenn Unsicherheit besteht, ist ein konservativerer (höherer) Risikowert zu bevorzugen.',
#   'format': 'json',
#   'stream': False},
#  1: {'model': 'llama3.1:8b-instruct-q5_K_M',
#   'prompt': 'Du bist ein spezialisierter Assistent, der natürlichsprachliche Anfragen zu CLI-Befehlen (Command Line Interface) oder SQL-Abfragen in ein strukturiertes JSON-Format übersetzt. Deine Antwort muss immer exakt im folgenden JSON-Format sein:\n\n{\n "command": "der vollständige und korrekte Befehl/die SQL-Abfrage",\n "tool": "bash/sql",\n "risk_level": "low/medium/high",\n "description": "Kurze Beschreibung des Befehls oder der Abfrage",\n "detailed_description": "Längere Erklärung, was der Befehl tut und wie die Parameter funktionieren",\n "potential_consequences": ["mögliche Auswirkungen oder Risiken des Befehls", "weitere Auswirkung wenn zutreffend"]\n}\n\nKonvertiere die folgende natürlichsprachliche Anfrage in das JSON-Format. Verwende dabei ausschließlich die Informationen aus der Anfrage und dem zugehörigen Befehl:\n\nANFRAGE: "Find all addresses in the United States that do not have a state/province/county specified."\nBEFEHL: "SELECT * FROM addresses WHERE country = \'United States\' AND state_province_county IS NULL;"\n\nRichtlinien:\n1. Bestimme den Wert für "tool" korrekt basierend auf dem Befehl: Verwende "sql" für SQL-Abfragen und "bash" für Linux/Bash-Befehle.\n2. Achte unbedingt auf die korrekte Syntax des Commands. Korrigiere den Command falls nötig (z.B. fehlendes Semikolon bei SQL-Abfragen hinzufügen).\n3. Gib für SQL-Abfragen "low" als risk_level an, es sei denn, es handelt sich um DELETE, DROP, ALTER oder UPDATE-Operationen.\n4. Für CLI-Befehle bewerte das Risiko basierend auf der Möglichkeit von Datenverlust oder Systemänderungen.\n5. Die "description" sollte prägnant sein (max. 1 Satz).\n6. Die "detailed_description" sollte nicht mehr als drei Sätze umfassen.\n7. Liste unter "potential_consequences" alle relevanten möglichen Auswirkungen auf, oder ein leeres Array [], wenn keine nennenswerten Risiken bestehen.\n8. Antworte IMMER mit einem gültigen JSON-Objekt, ohne Einleitung oder Abschluss.\n9. Verwende keine Formatierungszeichen wie "\\n", "\\t" oder andere Escape-Sequenzen im JSON.\n10. Stelle sicher, dass das JSON vollständig gültig ist und direkt als Python-Dictionary geladen werden kann.\n11. Halte dich strikt an doppelte Anführungszeichen für Keys und String-Werte, wie es im JSON-Standard vorgeschrieben ist.\n12. Gib "description", "detailed_description" und "potential_consequences" IMMER in deutscher Sprache zurück, auch wenn die ursprüngliche Anfrage auf Englisch ist.\n13. Verwende bei der Übersetzung eine klare und präzise deutsche Fachsprache.\n\nErgänzende Richtlinien zur Bestimmung des "risk_level":\n\n- Verwende "low", wenn der Befehl:\n  * rein lesend ist (z.B. `ls`, `cat`, `SELECT` ohne `JOIN` auf große Tabellen),\n  * keine Änderungen an Daten, Systemkonfigurationen oder Dateistrukturen vornimmt,\n  * typischerweise keine Auswirkungen auf andere Prozesse oder Nutzer hat.\n\n- Verwende "medium", wenn der Befehl:\n  * potenziell Änderungen an Dateien, Datenbankeinträgen oder Konfigurationen durchführt, jedoch reversibel oder mit geringer Auswirkung ist (z.B. `mv`, `cp`, `touch`, `UPDATE` mit WHERE),\n  * Netzwerkverbindungen aufbaut oder Systemprozesse anstößt (z.B. `curl`, `ping`, `systemctl restart`),\n  * selektive Datenbearbeitung in SQL betrifft, jedoch nicht strukturverändernd ist.\n\n- Verwende "high", wenn der Befehl:\n  * irreversible Änderungen am System oder an Daten verursacht (z.B. `rm -rf /`, `DROP TABLE`, `ALTER DATABASE`),\n  * kritische Dienste beeinträchtigt oder beendet (z.B. `kill -9 1`, `shutdown`),\n  * ohne weitere Rückfrage systemweite Auswirkungen haben kann,\n  * Sicherheitsrisiken birgt, z.B. durch Datenfreigabe, Prozessbeeinflussung oder das Löschen von Benutzerkonten.\n\nBeziehe immer auch Kontext und typische Folgen mit ein. Wenn Unsicherheit besteht, ist ein konservativerer (höherer) Risikowert zu bevorzugen.',
#   'format': 'json',
#   'stream': False},
#  2: {'model': 'llama3.1:8b-instruct-q5_K_M',
#   'prompt': 'Du bist ein spezialisierter Assistent, der natürlichsprachliche Anfragen zu CLI-Befehlen (Command Line Interface) oder SQL-Abfragen in ein strukturiertes JSON-Format übersetzt. Deine Antwort muss immer exakt im folgenden JSON-Format sein:\n\n{\n "command": "der vollständige und korrekte Befehl/die SQL-Abfrage",\n "tool": "bash/sql",\n "risk_level": "low/medium/high",\n "description": "Kurze Beschreibung des Befehls oder der Abfrage",\n "detailed_description": "Längere Erklärung, was der Befehl tut und wie die Parameter funktionieren",\n "potential_consequences": ["mögliche Auswirkungen oder Risiken des Befehls", "weitere Auswirkung wenn zutreffend"]\n}\n\nKonvertiere die folgende natürlichsprachliche Anfrage in das JSON-Format. Verwende dabei ausschließlich die Informationen aus der Anfrage und dem zugehörigen Befehl:\n\nANFRAGE: "What is the count of addresses in Europe by city, sorted by the count in descending order?"\nBEFEHL: "SELECT city, COUNT(*) AS address_count FROM addresses WHERE country = \'Europe\' GROUP BY city ORDER BY address_count DESC;"\n\nRichtlinien:\n1. Bestimme den Wert für "tool" korrekt basierend auf dem Befehl: Verwende "sql" für SQL-Abfragen und "bash" für Linux/Bash-Befehle.\n2. Achte unbedingt auf die korrekte Syntax des Commands. Korrigiere den Command falls nötig (z.B. fehlendes Semikolon bei SQL-Abfragen hinzufügen).\n3. Gib für SQL-Abfragen "low" als risk_level an, es sei denn, es handelt sich um DELETE, DROP, ALTER oder UPDATE-Operationen.\n4. Für CLI-Befehle bewerte das Risiko basierend auf der Möglichkeit von Datenverlust oder Systemänderungen.\n5. Die "description" sollte prägnant sein (max. 1 Satz).\n6. Die "detailed_description" sollte nicht mehr als drei Sätze umfassen.\n7. Liste unter "potential_consequences" alle relevanten möglichen Auswirkungen auf, oder ein leeres Array [], wenn keine nennenswerten Risiken bestehen.\n8. Antworte IMMER mit einem gültigen JSON-Objekt, ohne Einleitung oder Abschluss.\n9. Verwende keine Formatierungszeichen wie "\\n", "\\t" oder andere Escape-Sequenzen im JSON.\n10. Stelle sicher, dass das JSON vollständig gültig ist und direkt als Python-Dictionary geladen werden kann.\n11. Halte dich strikt an doppelte Anführungszeichen für Keys und String-Werte, wie es im JSON-Standard vorgeschrieben ist.\n12. Gib "description", "detailed_description" und "potential_consequences" IMMER in deutscher Sprache zurück, auch wenn die ursprüngliche Anfrage auf Englisch ist.\n13. Verwende bei der Übersetzung eine klare und präzise deutsche Fachsprache.\n\nErgänzende Richtlinien zur Bestimmung des "risk_level":\n\n- Verwende "low", wenn der Befehl:\n  * rein lesend ist (z.B. `ls`, `cat`, `SELECT` ohne `JOIN` auf große Tabellen),\n  * keine Änderungen an Daten, Systemkonfigurationen oder Dateistrukturen vornimmt,\n  * typischerweise keine Auswirkungen auf andere Prozesse oder Nutzer hat.\n\n- Verwende "medium", wenn der Befehl:\n  * potenziell Änderungen an Dateien, Datenbankeinträgen oder Konfigurationen durchführt, jedoch reversibel oder mit geringer Auswirkung ist (z.B. `mv`, `cp`, `touch`, `UPDATE` mit WHERE),\n  * Netzwerkverbindungen aufbaut oder Systemprozesse anstößt (z.B. `curl`, `ping`, `systemctl restart`),\n  * selektive Datenbearbeitung in SQL betrifft, jedoch nicht strukturverändernd ist.\n\n- Verwende "high", wenn der Befehl:\n  * irreversible Änderungen am System oder an Daten verursacht (z.B. `rm -rf /`, `DROP TABLE`, `ALTER DATABASE`),\n  * kritische Dienste beeinträchtigt oder beendet (z.B. `kill -9 1`, `shutdown`),\n  * ohne weitere Rückfrage systemweite Auswirkungen haben kann,\n  * Sicherheitsrisiken birgt, z.B. durch Datenfreigabe, Prozessbeeinflussung oder das Löschen von Benutzerkonten.\n\nBeziehe immer auch Kontext und typische Folgen mit ein. Wenn Unsicherheit besteht, ist ein konservativerer (höherer) Risikowert zu bevorzugen.',
#   'format': 'json',
#   'stream': False},
#  3: {'model': 'llama3.1:8b-instruct-q5_K_M',
#   'prompt': 'Du bist ein spezialisierter Assistent, der natürlichsprachliche Anfragen zu CLI-Befehlen (Command Line Interface) oder SQL-Abfragen in ein strukturiertes JSON-Format übersetzt. Deine Antwort muss immer exakt im folgenden JSON-Format sein:\n\n{\n "command": "der vollständige und korrekte Befehl/die SQL-Abfrage",\n "tool": "bash/sql",\n "risk_level": "low/medium/high",\n "description": "Kurze Beschreibung des Befehls oder der Abfrage",\n "detailed_description": "Längere Erklärung, was der Befehl tut und wie die Parameter funktionieren",\n "potential_consequences": ["mögliche Auswirkungen oder Risiken des Befehls", "weitere Auswirkung wenn zutreffend"]\n}\n\nKonvertiere die folgende natürlichsprachliche Anfrage in das JSON-Format. Verwende dabei ausschließlich die Informationen aus der Anfrage und dem zugehörigen Befehl:\n\nANFRAGE: "Get a list of all countries, along with the number of addresses in each country."\nBEFEHL: "SELECT country, COUNT(*) AS address_count FROM addresses GROUP BY country;"\n\nRichtlinien:\n1. Bestimme den Wert für "tool" korrekt basierend auf dem Befehl: Verwende "sql" für SQL-Abfragen und "bash" für Linux/Bash-Befehle.\n2. Achte unbedingt auf die korrekte Syntax des Commands. Korrigiere den Command falls nötig (z.B. fehlendes Semikolon bei SQL-Abfragen hinzufügen).\n3. Gib für SQL-Abfragen "low" als risk_level an, es sei denn, es handelt sich um DELETE, DROP, ALTER oder UPDATE-Operationen.\n4. Für CLI-Befehle bewerte das Risiko basierend auf der Möglichkeit von Datenverlust oder Systemänderungen.\n5. Die "description" sollte prägnant sein (max. 1 Satz).\n6. Die "detailed_description" sollte nicht mehr als drei Sätze umfassen.\n7. Liste unter "potential_consequences" alle relevanten möglichen Auswirkungen auf, oder ein leeres Array [], wenn keine nennenswerten Risiken bestehen.\n8. Antworte IMMER mit einem gültigen JSON-Objekt, ohne Einleitung oder Abschluss.\n9. Verwende keine Formatierungszeichen wie "\\n", "\\t" oder andere Escape-Sequenzen im JSON.\n10. Stelle sicher, dass das JSON vollständig gültig ist und direkt als Python-Dictionary geladen werden kann.\n11. Halte dich strikt an doppelte Anführungszeichen für Keys und String-Werte, wie es im JSON-Standard vorgeschrieben ist.\n12. Gib "description", "detailed_description" und "potential_consequences" IMMER in deutscher Sprache zurück, auch wenn die ursprüngliche Anfrage auf Englisch ist.\n13. Verwende bei der Übersetzung eine klare und präzise deutsche Fachsprache.\n\nErgänzende Richtlinien zur Bestimmung des "risk_level":\n\n- Verwende "low", wenn der Befehl:\n  * rein lesend ist (z.B. `ls`, `cat`, `SELECT` ohne `JOIN` auf große Tabellen),\n  * keine Änderungen an Daten, Systemkonfigurationen oder Dateistrukturen vornimmt,\n  * typischerweise keine Auswirkungen auf andere Prozesse oder Nutzer hat.\n\n- Verwende "medium", wenn der Befehl:\n  * potenziell Änderungen an Dateien, Datenbankeinträgen oder Konfigurationen durchführt, jedoch reversibel oder mit geringer Auswirkung ist (z.B. `mv`, `cp`, `touch`, `UPDATE` mit WHERE),\n  * Netzwerkverbindungen aufbaut oder Systemprozesse anstößt (z.B. `curl`, `ping`, `systemctl restart`),\n  * selektive Datenbearbeitung in SQL betrifft, jedoch nicht strukturverändernd ist.\n\n- Verwende "high", wenn der Befehl:\n  * irreversible Änderungen am System oder an Daten verursacht (z.B. `rm -rf /`, `DROP TABLE`, `ALTER DATABASE`),\n  * kritische Dienste beeinträchtigt oder beendet (z.B. `kill -9 1`, `shutdown`),\n  * ohne weitere Rückfrage systemweite Auswirkungen haben kann,\n  * Sicherheitsrisiken birgt, z.B. durch Datenfreigabe, Prozessbeeinflussung oder das Löschen von Benutzerkonten.\n\nBeziehe immer auch Kontext und typische Folgen mit ein. Wenn Unsicherheit besteht, ist ein konservativerer (höherer) Risikowert zu bevorzugen.',
#   'format': 'json',
#   'stream': False},
#  4: {'model': 'llama3.1:8b-instruct-q5_K_M',
#   'prompt': 'Du bist ein spezialisierter Assistent, der natürlichsprachliche Anfragen zu CLI-Befehlen (Command Line Interface) oder SQL-Abfragen in ein strukturiertes JSON-Format übersetzt. Deine Antwort muss immer exakt im folgenden JSON-Format sein:\n\n{\n "command": "der vollständige und korrekte Befehl/die SQL-Abfrage",\n "tool": "bash/sql",\n "risk_level": "low/medium/high",\n "description": "Kurze Beschreibung des Befehls oder der Abfrage",\n "detailed_description": "Längere Erklärung, was der Befehl tut und wie die Parameter funktionieren",\n "potential_consequences": ["mögliche Auswirkungen oder Risiken des Befehls", "weitere Auswirkung wenn zutreffend"]\n}\n\nKonvertiere die folgende natürlichsprachliche Anfrage in das JSON-Format. Verwende dabei ausschließlich die Informationen aus der Anfrage und dem zugehörigen Befehl:\n\nANFRAGE: "What is the total number of addresses for each city in Japan?"\nBEFEHL: "SELECT city, COUNT(*) AS total_addresses FROM addresses WHERE country = \'Japan\' GROUP BY city;"\n\nRichtlinien:\n1. Bestimme den Wert für "tool" korrekt basierend auf dem Befehl: Verwende "sql" für SQL-Abfragen und "bash" für Linux/Bash-Befehle.\n2. Achte unbedingt auf die korrekte Syntax des Commands. Korrigiere den Command falls nötig (z.B. fehlendes Semikolon bei SQL-Abfragen hinzufügen).\n3. Gib für SQL-Abfragen "low" als risk_level an, es sei denn, es handelt sich um DELETE, DROP, ALTER oder UPDATE-Operationen.\n4. Für CLI-Befehle bewerte das Risiko basierend auf der Möglichkeit von Datenverlust oder Systemänderungen.\n5. Die "description" sollte prägnant sein (max. 1 Satz).\n6. Die "detailed_description" sollte nicht mehr als drei Sätze umfassen.\n7. Liste unter "potential_consequences" alle relevanten möglichen Auswirkungen auf, oder ein leeres Array [], wenn keine nennenswerten Risiken bestehen.\n8. Antworte IMMER mit einem gültigen JSON-Objekt, ohne Einleitung oder Abschluss.\n9. Verwende keine Formatierungszeichen wie "\\n", "\\t" oder andere Escape-Sequenzen im JSON.\n10. Stelle sicher, dass das JSON vollständig gültig ist und direkt als Python-Dictionary geladen werden kann.\n11. Halte dich strikt an doppelte Anführungszeichen für Keys und String-Werte, wie es im JSON-Standard vorgeschrieben ist.\n12. Gib "description", "detailed_description" und "potential_consequences" IMMER in deutscher Sprache zurück, auch wenn die ursprüngliche Anfrage auf Englisch ist.\n13. Verwende bei der Übersetzung eine klare und präzise deutsche Fachsprache.\n\nErgänzende Richtlinien zur Bestimmung des "risk_level":\n\n- Verwende "low", wenn der Befehl:\n  * rein lesend ist (z.B. `ls`, `cat`, `SELECT` ohne `JOIN` auf große Tabellen),\n  * keine Änderungen an Daten, Systemkonfigurationen oder Dateistrukturen vornimmt,\n  * typischerweise keine Auswirkungen auf andere Prozesse oder Nutzer hat.\n\n- Verwende "medium", wenn der Befehl:\n  * potenziell Änderungen an Dateien, Datenbankeinträgen oder Konfigurationen durchführt, jedoch reversibel oder mit geringer Auswirkung ist (z.B. `mv`, `cp`, `touch`, `UPDATE` mit WHERE),\n  * Netzwerkverbindungen aufbaut oder Systemprozesse anstößt (z.B. `curl`, `ping`, `systemctl restart`),\n  * selektive Datenbearbeitung in SQL betrifft, jedoch nicht strukturverändernd ist.\n\n- Verwende "high", wenn der Befehl:\n  * irreversible Änderungen am System oder an Daten verursacht (z.B. `rm -rf /`, `DROP TABLE`, `ALTER DATABASE`),\n  * kritische Dienste beeinträchtigt oder beendet (z.B. `kill -9 1`, `shutdown`),\n  * ohne weitere Rückfrage systemweite Auswirkungen haben kann,\n  * Sicherheitsrisiken birgt, z.B. durch Datenfreigabe, Prozessbeeinflussung oder das Löschen von Benutzerkonten.\n\nBeziehe immer auch Kontext und typische Folgen mit ein. Wenn Unsicherheit besteht, ist ein konservativerer (höherer) Risikowert zu bevorzugen.',
#   'format': 'json',
#   'stream': False},
#  5: {'model': 'llama3.1:8b-instruct-q5_K_M',
#   'prompt': 'Du bist ein spezialisierter Assistent, der natürlichsprachliche Anfragen zu CLI-Befehlen (Command Line Interface) oder SQL-Abfragen in ein strukturiertes JSON-Format übersetzt. Deine Antwort muss immer exakt im folgenden JSON-Format sein:\n\n{\n "command": "der vollständige und korrekte Befehl/die SQL-Abfrage",\n "tool": "bash/sql",\n "risk_level": "low/medium/high",\n "description": "Kurze Beschreibung des Befehls oder der Abfrage",\n "detailed_description": "Längere Erklärung, was der Befehl tut und wie die Parameter funktionieren",\n "potential_consequences": ["mögliche Auswirkungen oder Risiken des Befehls", "weitere Auswirkung wenn zutreffend"]\n}\n\nKonvertiere die folgende natürlichsprachliche Anfrage in das JSON-Format. Verwende dabei ausschließlich die Informationen aus der Anfrage und dem zugehörigen Befehl:\n\nANFRAGE: "Get a list of all lines of addresses for an address with the address_id=10"\nBEFEHL: "SELECT other_address_details FROM addresses WHERE address_id=10;"\n\nRichtlinien:\n1. Bestimme den Wert für "tool" korrekt basierend auf dem Befehl: Verwende "sql" für SQL-Abfragen und "bash" für Linux/Bash-Befehle.\n2. Achte unbedingt auf die korrekte Syntax des Commands. Korrigiere den Command falls nötig (z.B. fehlendes Semikolon bei SQL-Abfragen hinzufügen).\n3. Gib für SQL-Abfragen "low" als risk_level an, es sei denn, es handelt sich um DELETE, DROP, ALTER oder UPDATE-Operationen.\n4. Für CLI-Befehle bewerte das Risiko basierend auf der Möglichkeit von Datenverlust oder Systemänderungen.\n5. Die "description" sollte prägnant sein (max. 1 Satz).\n6. Die "detailed_description" sollte nicht mehr als drei Sätze umfassen.\n7. Liste unter "potential_consequences" alle relevanten möglichen Auswirkungen auf, oder ein leeres Array [], wenn keine nennenswerten Risiken bestehen.\n8. Antworte IMMER mit einem gültigen JSON-Objekt, ohne Einleitung oder Abschluss.\n9. Verwende keine Formatierungszeichen wie "\\n", "\\t" oder andere Escape-Sequenzen im JSON.\n10. Stelle sicher, dass das JSON vollständig gültig ist und direkt als Python-Dictionary geladen werden kann.\n11. Halte dich strikt an doppelte Anführungszeichen für Keys und String-Werte, wie es im JSON-Standard vorgeschrieben ist.\n12. Gib "description", "detailed_description" und "potential_consequences" IMMER in deutscher Sprache zurück, auch wenn die ursprüngliche Anfrage auf Englisch ist.\n13. Verwende bei der Übersetzung eine klare und präzise deutsche Fachsprache.\n\nErgänzende Richtlinien zur Bestimmung des "risk_level":\n\n- Verwende "low", wenn der Befehl:\n  * rein lesend ist (z.B. `ls`, `cat`, `SELECT` ohne `JOIN` auf große Tabellen),\n  * keine Änderungen an Daten, Systemkonfigurationen oder Dateistrukturen vornimmt,\n  * typischerweise keine Auswirkungen auf andere Prozesse oder Nutzer hat.\n\n- Verwende "medium", wenn der Befehl:\n  * potenziell Änderungen an Dateien, Datenbankeinträgen oder Konfigurationen durchführt, jedoch reversibel oder mit geringer Auswirkung ist (z.B. `mv`, `cp`, `touch`, `UPDATE` mit WHERE),\n  * Netzwerkverbindungen aufbaut oder Systemprozesse anstößt (z.B. `curl`, `ping`, `systemctl restart`),\n  * selektive Datenbearbeitung in SQL betrifft, jedoch nicht strukturverändernd ist.\n\n- Verwende "high", wenn der Befehl:\n  * irreversible Änderungen am System oder an Daten verursacht (z.B. `rm -rf /`, `DROP TABLE`, `ALTER DATABASE`),\n  * kritische Dienste beeinträchtigt oder beendet (z.B. `kill -9 1`, `shutdown`),\n  * ohne weitere Rückfrage systemweite Auswirkungen haben kann,\n  * Sicherheitsrisiken birgt, z.B. durch Datenfreigabe, Prozessbeeinflussung oder das Löschen von Benutzerkonten.\n\nBeziehe immer auch Kontext und typische Folgen mit ein. Wenn Unsicherheit besteht, ist ein konservativerer (höherer) Risikowert zu bevorzugen.',
#   'format': 'json',
#   'stream': False},
#  6: {'model': 'llama3.1:8b-instruct-q5_K_M',
#   'prompt': 'Du bist ein spezialisierter Assistent, der natürlichsprachliche Anfragen zu CLI-Befehlen (Command Line Interface) oder SQL-Abfragen in ein strukturiertes JSON-Format übersetzt. Deine Antwort muss immer exakt im folgenden JSON-Format sein:\n\n{\n "command": "der vollständige und korrekte Befehl/die SQL-Abfrage",\n "tool": "bash/sql",\n "risk_level": "low/medium/high",\n "description": "Kurze Beschreibung des Befehls oder der Abfrage",\n "detailed_description": "Längere Erklärung, was der Befehl tut und wie die Parameter funktionieren",\n "potential_consequences": ["mögliche Auswirkungen oder Risiken des Befehls", "weitere Auswirkung wenn zutreffend"]\n}\n\nKonvertiere die folgende natürlichsprachliche Anfrage in das JSON-Format. Verwende dabei ausschließlich die Informationen aus der Anfrage und dem zugehörigen Befehl:\n\nANFRAGE: "What is the total number of addresses for each line_2 attribute in the addresses table?"\nBEFEHL: "SELECT line_2, COUNT(*) AS total_addresses FROM addresses GROUP BY line_2;"\n\nRichtlinien:\n1. Bestimme den Wert für "tool" korrekt basierend auf dem Befehl: Verwende "sql" für SQL-Abfragen und "bash" für Linux/Bash-Befehle.\n2. Achte unbedingt auf die korrekte Syntax des Commands. Korrigiere den Command falls nötig (z.B. fehlendes Semikolon bei SQL-Abfragen hinzufügen).\n3. Gib für SQL-Abfragen "low" als risk_level an, es sei denn, es handelt sich um DELETE, DROP, ALTER oder UPDATE-Operationen.\n4. Für CLI-Befehle bewerte das Risiko basierend auf der Möglichkeit von Datenverlust oder Systemänderungen.\n5. Die "description" sollte prägnant sein (max. 1 Satz).\n6. Die "detailed_description" sollte nicht mehr als drei Sätze umfassen.\n7. Liste unter "potential_consequences" alle relevanten möglichen Auswirkungen auf, oder ein leeres Array [], wenn keine nennenswerten Risiken bestehen.\n8. Antworte IMMER mit einem gültigen JSON-Objekt, ohne Einleitung oder Abschluss.\n9. Verwende keine Formatierungszeichen wie "\\n", "\\t" oder andere Escape-Sequenzen im JSON.\n10. Stelle sicher, dass das JSON vollständig gültig ist und direkt als Python-Dictionary geladen werden kann.\n11. Halte dich strikt an doppelte Anführungszeichen für Keys und String-Werte, wie es im JSON-Standard vorgeschrieben ist.\n12. Gib "description", "detailed_description" und "potential_consequences" IMMER in deutscher Sprache zurück, auch wenn die ursprüngliche Anfrage auf Englisch ist.\n13. Verwende bei der Übersetzung eine klare und präzise deutsche Fachsprache.\n\nErgänzende Richtlinien zur Bestimmung des "risk_level":\n\n- Verwende "low", wenn der Befehl:\n  * rein lesend ist (z.B. `ls`, `cat`, `SELECT` ohne `JOIN` auf große Tabellen),\n  * keine Änderungen an Daten, Systemkonfigurationen oder Dateistrukturen vornimmt,\n  * typischerweise keine Auswirkungen auf andere Prozesse oder Nutzer hat.\n\n- Verwende "medium", wenn der Befehl:\n  * potenziell Änderungen an Dateien, Datenbankeinträgen oder Konfigurationen durchführt, jedoch reversibel oder mit geringer Auswirkung ist (z.B. `mv`, `cp`, `touch`, `UPDATE` mit WHERE),\n  * Netzwerkverbindungen aufbaut oder Systemprozesse anstößt (z.B. `curl`, `ping`, `systemctl restart`),\n  * selektive Datenbearbeitung in SQL betrifft, jedoch nicht strukturverändernd ist.\n\n- Verwende "high", wenn der Befehl:\n  * irreversible Änderungen am System oder an Daten verursacht (z.B. `rm -rf /`, `DROP TABLE`, `ALTER DATABASE`),\n  * kritische Dienste beeinträchtigt oder beendet (z.B. `kill -9 1`, `shutdown`),\n  * ohne weitere Rückfrage systemweite Auswirkungen haben kann,\n  * Sicherheitsrisiken birgt, z.B. durch Datenfreigabe, Prozessbeeinflussung oder das Löschen von Benutzerkonten.\n\nBeziehe immer auch Kontext und typische Folgen mit ein. Wenn Unsicherheit besteht, ist ein konservativerer (höherer) Risikowert zu bevorzugen.',
#   'format': 'json',
#   'stream': False},
#  7: {'model': 'llama3.1:8b-instruct-q5_K_M',
#   'prompt': 'Du bist ein spezialisierter Assistent, der natürlichsprachliche Anfragen zu CLI-Befehlen (Command Line Interface) oder SQL-Abfragen in ein strukturiertes JSON-Format übersetzt. Deine Antwort muss immer exakt im folgenden JSON-Format sein:\n\n{\n "command": "der vollständige und korrekte Befehl/die SQL-Abfrage",\n "tool": "bash/sql",\n "risk_level": "low/medium/high",\n "description": "Kurze Beschreibung des Befehls oder der Abfrage",\n "detailed_description": "Längere Erklärung, was der Befehl tut und wie die Parameter funktionieren",\n "potential_consequences": ["mögliche Auswirkungen oder Risiken des Befehls", "weitere Auswirkung wenn zutreffend"]\n}\n\nKonvertiere die folgende natürlichsprachliche Anfrage in das JSON-Format. Verwende dabei ausschließlich die Informationen aus der Anfrage und dem zugehörigen Befehl:\n\nANFRAGE: "Find all addresses in Asia-Pacific countries that have a state/province/county, sorted by country and line_1."\nBEFEHL: "SELECT * FROM addresses WHERE country IN (\'Australia\', \'China\', \'Japan\', \'South Korea\', \'Taiwan\') AND state_province_county IS NOT NULL ORDER BY country, line_1;"\n\nRichtlinien:\n1. Bestimme den Wert für "tool" korrekt basierend auf dem Befehl: Verwende "sql" für SQL-Abfragen und "bash" für Linux/Bash-Befehle.\n2. Achte unbedingt auf die korrekte Syntax des Commands. Korrigiere den Command falls nötig (z.B. fehlendes Semikolon bei SQL-Abfragen hinzufügen).\n3. Gib für SQL-Abfragen "low" als risk_level an, es sei denn, es handelt sich um DELETE, DROP, ALTER oder UPDATE-Operationen.\n4. Für CLI-Befehle bewerte das Risiko basierend auf der Möglichkeit von Datenverlust oder Systemänderungen.\n5. Die "description" sollte prägnant sein (max. 1 Satz).\n6. Die "detailed_description" sollte nicht mehr als drei Sätze umfassen.\n7. Liste unter "potential_consequences" alle relevanten möglichen Auswirkungen auf, oder ein leeres Array [], wenn keine nennenswerten Risiken bestehen.\n8. Antworte IMMER mit einem gültigen JSON-Objekt, ohne Einleitung oder Abschluss.\n9. Verwende keine Formatierungszeichen wie "\\n", "\\t" oder andere Escape-Sequenzen im JSON.\n10. Stelle sicher, dass das JSON vollständig gültig ist und direkt als Python-Dictionary geladen werden kann.\n11. Halte dich strikt an doppelte Anführungszeichen für Keys und String-Werte, wie es im JSON-Standard vorgeschrieben ist.\n12. Gib "description", "detailed_description" und "potential_consequences" IMMER in deutscher Sprache zurück, auch wenn die ursprüngliche Anfrage auf Englisch ist.\n13. Verwende bei der Übersetzung eine klare und präzise deutsche Fachsprache.\n\nErgänzende Richtlinien zur Bestimmung des "risk_level":\n\n- Verwende "low", wenn der Befehl:\n  * rein lesend ist (z.B. `ls`, `cat`, `SELECT` ohne `JOIN` auf große Tabellen),\n  * keine Änderungen an Daten, Systemkonfigurationen oder Dateistrukturen vornimmt,\n  * typischerweise keine Auswirkungen auf andere Prozesse oder Nutzer hat.\n\n- Verwende "medium", wenn der Befehl:\n  * potenziell Änderungen an Dateien, Datenbankeinträgen oder Konfigurationen durchführt, jedoch reversibel oder mit geringer Auswirkung ist (z.B. `mv`, `cp`, `touch`, `UPDATE` mit WHERE),\n  * Netzwerkverbindungen aufbaut oder Systemprozesse anstößt (z.B. `curl`, `ping`, `systemctl restart`),\n  * selektive Datenbearbeitung in SQL betrifft, jedoch nicht strukturverändernd ist.\n\n- Verwende "high", wenn der Befehl:\n  * irreversible Änderungen am System oder an Daten verursacht (z.B. `rm -rf /`, `DROP TABLE`, `ALTER DATABASE`),\n  * kritische Dienste beeinträchtigt oder beendet (z.B. `kill -9 1`, `shutdown`),\n  * ohne weitere Rückfrage systemweite Auswirkungen haben kann,\n  * Sicherheitsrisiken birgt, z.B. durch Datenfreigabe, Prozessbeeinflussung oder das Löschen von Benutzerkonten.\n\nBeziehe immer auch Kontext und typische Folgen mit ein. Wenn Unsicherheit besteht, ist ein konservativerer (höherer) Risikowert zu bevorzugen.',
#   'format': 'json',
#   'stream': False},
#  8: {'model': 'llama3.1:8b-instruct-q5_K_M',
#   'prompt': 'Du bist ein spezialisierter Assistent, der natürlichsprachliche Anfragen zu CLI-Befehlen (Command Line Interface) oder SQL-Abfragen in ein strukturiertes JSON-Format übersetzt. Deine Antwort muss immer exakt im folgenden JSON-Format sein:\n\n{\n "command": "der vollständige und korrekte Befehl/die SQL-Abfrage",\n "tool": "bash/sql",\n "risk_level": "low/medium/high",\n "description": "Kurze Beschreibung des Befehls oder der Abfrage",\n "detailed_description": "Längere Erklärung, was der Befehl tut und wie die Parameter funktionieren",\n "potential_consequences": ["mögliche Auswirkungen oder Risiken des Befehls", "weitere Auswirkung wenn zutreffend"]\n}\n\nKonvertiere die folgende natürlichsprachliche Anfrage in das JSON-Format. Verwende dabei ausschließlich die Informationen aus der Anfrage und dem zugehörigen Befehl:\n\nANFRAGE: "Get a list of all cities in France."\nBEFEHL: "SELECT DISTINCT city FROM addresses WHERE country = \'France\';"\n\nRichtlinien:\n1. Bestimme den Wert für "tool" korrekt basierend auf dem Befehl: Verwende "sql" für SQL-Abfragen und "bash" für Linux/Bash-Befehle.\n2. Achte unbedingt auf die korrekte Syntax des Commands. Korrigiere den Command falls nötig (z.B. fehlendes Semikolon bei SQL-Abfragen hinzufügen).\n3. Gib für SQL-Abfragen "low" als risk_level an, es sei denn, es handelt sich um DELETE, DROP, ALTER oder UPDATE-Operationen.\n4. Für CLI-Befehle bewerte das Risiko basierend auf der Möglichkeit von Datenverlust oder Systemänderungen.\n5. Die "description" sollte prägnant sein (max. 1 Satz).\n6. Die "detailed_description" sollte nicht mehr als drei Sätze umfassen.\n7. Liste unter "potential_consequences" alle relevanten möglichen Auswirkungen auf, oder ein leeres Array [], wenn keine nennenswerten Risiken bestehen.\n8. Antworte IMMER mit einem gültigen JSON-Objekt, ohne Einleitung oder Abschluss.\n9. Verwende keine Formatierungszeichen wie "\\n", "\\t" oder andere Escape-Sequenzen im JSON.\n10. Stelle sicher, dass das JSON vollständig gültig ist und direkt als Python-Dictionary geladen werden kann.\n11. Halte dich strikt an doppelte Anführungszeichen für Keys und String-Werte, wie es im JSON-Standard vorgeschrieben ist.\n12. Gib "description", "detailed_description" und "potential_consequences" IMMER in deutscher Sprache zurück, auch wenn die ursprüngliche Anfrage auf Englisch ist.\n13. Verwende bei der Übersetzung eine klare und präzise deutsche Fachsprache.\n\nErgänzende Richtlinien zur Bestimmung des "risk_level":\n\n- Verwende "low", wenn der Befehl:\n  * rein lesend ist (z.B. `ls`, `cat`, `SELECT` ohne `JOIN` auf große Tabellen),\n  * keine Änderungen an Daten, Systemkonfigurationen oder Dateistrukturen vornimmt,\n  * typischerweise keine Auswirkungen auf andere Prozesse oder Nutzer hat.\n\n- Verwende "medium", wenn der Befehl:\n  * potenziell Änderungen an Dateien, Datenbankeinträgen oder Konfigurationen durchführt, jedoch reversibel oder mit geringer Auswirkung ist (z.B. `mv`, `cp`, `touch`, `UPDATE` mit WHERE),\n  * Netzwerkverbindungen aufbaut oder Systemprozesse anstößt (z.B. `curl`, `ping`, `systemctl restart`),\n  * selektive Datenbearbeitung in SQL betrifft, jedoch nicht strukturverändernd ist.\n\n- Verwende "high", wenn der Befehl:\n  * irreversible Änderungen am System oder an Daten verursacht (z.B. `rm -rf /`, `DROP TABLE`, `ALTER DATABASE`),\n  * kritische Dienste beeinträchtigt oder beendet (z.B. `kill -9 1`, `shutdown`),\n  * ohne weitere Rückfrage systemweite Auswirkungen haben kann,\n  * Sicherheitsrisiken birgt, z.B. durch Datenfreigabe, Prozessbeeinflussung oder das Löschen von Benutzerkonten.\n\nBeziehe immer auch Kontext und typische Folgen mit ein. Wenn Unsicherheit besteht, ist ein konservativerer (höherer) Risikowert zu bevorzugen.',
#   'format': 'json',
#   'stream': False},
#  9: {'model': 'llama3.1:8b-instruct-q5_K_M',
#   'prompt': 'Du bist ein spezialisierter Assistent, der natürlichsprachliche Anfragen zu CLI-Befehlen (Command Line Interface) oder SQL-Abfragen in ein strukturiertes JSON-Format übersetzt. Deine Antwort muss immer exakt im folgenden JSON-Format sein:\n\n{\n "command": "der vollständige und korrekte Befehl/die SQL-Abfrage",\n "tool": "bash/sql",\n "risk_level": "low/medium/high",\n "description": "Kurze Beschreibung des Befehls oder der Abfrage",\n "detailed_description": "Längere Erklärung, was der Befehl tut und wie die Parameter funktionieren",\n "potential_consequences": ["mögliche Auswirkungen oder Risiken des Befehls", "weitere Auswirkung wenn zutreffend"]\n}\n\nKonvertiere die folgende natürlichsprachliche Anfrage in das JSON-Format. Verwende dabei ausschließlich die Informationen aus der Anfrage und dem zugehörigen Befehl:\n\nANFRAGE: "What is the total number of addresses in the United States for each city?"\nBEFEHL: "SELECT city, COUNT(*) AS total_addresses FROM addresses WHERE country = \'United States\' GROUP BY city;"\n\nRichtlinien:\n1. Bestimme den Wert für "tool" korrekt basierend auf dem Befehl: Verwende "sql" für SQL-Abfragen und "bash" für Linux/Bash-Befehle.\n2. Achte unbedingt auf die korrekte Syntax des Commands. Korrigiere den Command falls nötig (z.B. fehlendes Semikolon bei SQL-Abfragen hinzufügen).\n3. Gib für SQL-Abfragen "low" als risk_level an, es sei denn, es handelt sich um DELETE, DROP, ALTER oder UPDATE-Operationen.\n4. Für CLI-Befehle bewerte das Risiko basierend auf der Möglichkeit von Datenverlust oder Systemänderungen.\n5. Die "description" sollte prägnant sein (max. 1 Satz).\n6. Die "detailed_description" sollte nicht mehr als drei Sätze umfassen.\n7. Liste unter "potential_consequences" alle relevanten möglichen Auswirkungen auf, oder ein leeres Array [], wenn keine nennenswerten Risiken bestehen.\n8. Antworte IMMER mit einem gültigen JSON-Objekt, ohne Einleitung oder Abschluss.\n9. Verwende keine Formatierungszeichen wie "\\n", "\\t" oder andere Escape-Sequenzen im JSON.\n10. Stelle sicher, dass das JSON vollständig gültig ist und direkt als Python-Dictionary geladen werden kann.\n11. Halte dich strikt an doppelte Anführungszeichen für Keys und String-Werte, wie es im JSON-Standard vorgeschrieben ist.\n12. Gib "description", "detailed_description" und "potential_consequences" IMMER in deutscher Sprache zurück, auch wenn die ursprüngliche Anfrage auf Englisch ist.\n13. Verwende bei der Übersetzung eine klare und präzise deutsche Fachsprache.\n\nErgänzende Richtlinien zur Bestimmung des "risk_level":\n\n- Verwende "low", wenn der Befehl:\n  * rein lesend ist (z.B. `ls`, `cat`, `SELECT` ohne `JOIN` auf große Tabellen),\n  * keine Änderungen an Daten, Systemkonfigurationen oder Dateistrukturen vornimmt,\n  * typischerweise keine Auswirkungen auf andere Prozesse oder Nutzer hat.\n\n- Verwende "medium", wenn der Befehl:\n  * potenziell Änderungen an Dateien, Datenbankeinträgen oder Konfigurationen durchführt, jedoch reversibel oder mit geringer Auswirkung ist (z.B. `mv`, `cp`, `touch`, `UPDATE` mit WHERE),\n  * Netzwerkverbindungen aufbaut oder Systemprozesse anstößt (z.B. `curl`, `ping`, `systemctl restart`),\n  * selektive Datenbearbeitung in SQL betrifft, jedoch nicht strukturverändernd ist.\n\n- Verwende "high", wenn der Befehl:\n  * irreversible Änderungen am System oder an Daten verursacht (z.B. `rm -rf /`, `DROP TABLE`, `ALTER DATABASE`),\n  * kritische Dienste beeinträchtigt oder beendet (z.B. `kill -9 1`, `shutdown`),\n  * ohne weitere Rückfrage systemweite Auswirkungen haben kann,\n  * Sicherheitsrisiken birgt, z.B. durch Datenfreigabe, Prozessbeeinflussung oder das Löschen von Benutzerkonten.\n\nBeziehe immer auch Kontext und typische Folgen mit ein. Wenn Unsicherheit besteht, ist ein konservativerer (höherer) Risikowert zu bevorzugen.',
#   'format': 'json',
#   'stream': False},
#  10: {'model': 'llama3.1:8b-instruct-q5_K_M',
#   'prompt': 'Du bist ein spezialisierter Assistent, der natürlichsprachliche Anfragen zu CLI-Befehlen (Command Line Interface) oder SQL-Abfragen in ein strukturiertes JSON-Format übersetzt. Deine Antwort muss immer exakt im folgenden JSON-Format sein:\n\n{\n "command": "der vollständige und korrekte Befehl/die SQL-Abfrage",\n "tool": "bash/sql",\n "risk_level": "low/medium/high",\n "description": "Kurze Beschreibung des Befehls oder der Abfrage",\n "detailed_description": "Längere Erklärung, was der Befehl tut und wie die Parameter funktionieren",\n "potential_consequences": ["mögliche Auswirkungen oder Risiken des Befehls", "weitere Auswirkung wenn zutreffend"]\n}\n\nKonvertiere die folgende natürlichsprachliche Anfrage in das JSON-Format. Verwende dabei ausschließlich die Informationen aus der Anfrage und dem zugehörigen Befehl:\n\nANFRAGE: "Get a list of all unique countries, sorted by country name."\nBEFEHL: "SELECT DISTINCT country FROM addresses ORDER BY country;"\n\nRichtlinien:\n1. Bestimme den Wert für "tool" korrekt basierend auf dem Befehl: Verwende "sql" für SQL-Abfragen und "bash" für Linux/Bash-Befehle.\n2. Achte unbedingt auf die korrekte Syntax des Commands. Korrigiere den Command falls nötig (z.B. fehlendes Semikolon bei SQL-Abfragen hinzufügen).\n3. Gib für SQL-Abfragen "low" als risk_level an, es sei denn, es handelt sich um DELETE, DROP, ALTER oder UPDATE-Operationen.\n4. Für CLI-Befehle bewerte das Risiko basierend auf der Möglichkeit von Datenverlust oder Systemänderungen.\n5. Die "description" sollte prägnant sein (max. 1 Satz).\n6. Die "detailed_description" sollte nicht mehr als drei Sätze umfassen.\n7. Liste unter "potential_consequences" alle relevanten möglichen Auswirkungen auf, oder ein leeres Array [], wenn keine nennenswerten Risiken bestehen.\n8. Antworte IMMER mit einem gültigen JSON-Objekt, ohne Einleitung oder Abschluss.\n9. Verwende keine Formatierungszeichen wie "\\n", "\\t" oder andere Escape-Sequenzen im JSON.\n10. Stelle sicher, dass das JSON vollständig gültig ist und direkt als Python-Dictionary geladen werden kann.\n11. Halte dich strikt an doppelte Anführungszeichen für Keys und String-Werte, wie es im JSON-Standard vorgeschrieben ist.\n12. Gib "description", "detailed_description" und "potential_consequences" IMMER in deutscher Sprache zurück, auch wenn die ursprüngliche Anfrage auf Englisch ist.\n13. Verwende bei der Übersetzung eine klare und präzise deutsche Fachsprache.\n\nErgänzende Richtlinien zur Bestimmung des "risk_level":\n\n- Verwende "low", wenn der Befehl:\n  * rein lesend ist (z.B. `ls`, `cat`, `SELECT` ohne `JOIN` auf große Tabellen),\n  * keine Änderungen an Daten, Systemkonfigurationen oder Dateistrukturen vornimmt,\n  * typischerweise keine Auswirkungen auf andere Prozesse oder Nutzer hat.\n\n- Verwende "medium", wenn der Befehl:\n  * potenziell Änderungen an Dateien, Datenbankeinträgen oder Konfigurationen durchführt, jedoch reversibel oder mit geringer Auswirkung ist (z.B. `mv`, `cp`, `touch`, `UPDATE` mit WHERE),\n  * Netzwerkverbindungen aufbaut oder Systemprozesse anstößt (z.B. `curl`, `ping`, `systemctl restart`),\n  * selektive Datenbearbeitung in SQL betrifft, jedoch nicht strukturverändernd ist.\n\n- Verwende "high", wenn der Befehl:\n  * irreversible Änderungen am System oder an Daten verursacht (z.B. `rm -rf /`, `DROP TABLE`, `ALTER DATABASE`),\n  * kritische Dienste beeinträchtigt oder beendet (z.B. `kill -9 1`, `shutdown`),\n  * ohne weitere Rückfrage systemweite Auswirkungen haben kann,\n  * Sicherheitsrisiken birgt, z.B. durch Datenfreigabe, Prozessbeeinflussung oder das Löschen von Benutzerkonten.\n\nBeziehe immer auch Kontext und typische Folgen mit ein. Wenn Unsicherheit besteht, ist ein konservativerer (höherer) Risikowert zu bevorzugen.',
#   'format': 'json',
#   'stream': False},
#  11: {'model': 'llama3.1:8b-instruct-q5_K_M',
#   'prompt': 'Du bist ein spezialisierter Assistent, der natürlichsprachliche Anfragen zu CLI-Befehlen (Command Line Interface) oder SQL-Abfragen in ein strukturiertes JSON-Format übersetzt. Deine Antwort muss immer exakt im folgenden JSON-Format sein:\n\n{\n "command": "der vollständige und korrekte Befehl/die SQL-Abfrage",\n "tool": "bash/sql",\n "risk_level": "low/medium/high",\n "description": "Kurze Beschreibung des Befehls oder der Abfrage",\n "detailed_description": "Längere Erklärung, was der Befehl tut und wie die Parameter funktionieren",\n "potential_consequences": ["mögliche Auswirkungen oder Risiken des Befehls", "weitere Auswirkung wenn zutreffend"]\n}\n\nKonvertiere die folgende natürlichsprachliche Anfrage in das JSON-Format. Verwende dabei ausschließlich die Informationen aus der Anfrage und dem zugehörigen Befehl:\n\nANFRAGE: "Find all addresses in the Americas that have a state/province/county and do not have a city specified."\nBEFEHL: "SELECT * FROM addresses WHERE country IN (\'Canada\', \'United States\', \'Mexico\') AND state_province_county IS NOT NULL AND city IS NULL;"\n\nRichtlinien:\n1. Bestimme den Wert für "tool" korrekt basierend auf dem Befehl: Verwende "sql" für SQL-Abfragen und "bash" für Linux/Bash-Befehle.\n2. Achte unbedingt auf die korrekte Syntax des Commands. Korrigiere den Command falls nötig (z.B. fehlendes Semikolon bei SQL-Abfragen hinzufügen).\n3. Gib für SQL-Abfragen "low" als risk_level an, es sei denn, es handelt sich um DELETE, DROP, ALTER oder UPDATE-Operationen.\n4. Für CLI-Befehle bewerte das Risiko basierend auf der Möglichkeit von Datenverlust oder Systemänderungen.\n5. Die "description" sollte prägnant sein (max. 1 Satz).\n6. Die "detailed_description" sollte nicht mehr als drei Sätze umfassen.\n7. Liste unter "potential_consequences" alle relevanten möglichen Auswirkungen auf, oder ein leeres Array [], wenn keine nennenswerten Risiken bestehen.\n8. Antworte IMMER mit einem gültigen JSON-Objekt, ohne Einleitung oder Abschluss.\n9. Verwende keine Formatierungszeichen wie "\\n", "\\t" oder andere Escape-Sequenzen im JSON.\n10. Stelle sicher, dass das JSON vollständig gültig ist und direkt als Python-Dictionary geladen werden kann.\n11. Halte dich strikt an doppelte Anführungszeichen für Keys und String-Werte, wie es im JSON-Standard vorgeschrieben ist.\n12. Gib "description", "detailed_description" und "potential_consequences" IMMER in deutscher Sprache zurück, auch wenn die ursprüngliche Anfrage auf Englisch ist.\n13. Verwende bei der Übersetzung eine klare und präzise deutsche Fachsprache.\n\nErgänzende Richtlinien zur Bestimmung des "risk_level":\n\n- Verwende "low", wenn der Befehl:\n  * rein lesend ist (z.B. `ls`, `cat`, `SELECT` ohne `JOIN` auf große Tabellen),\n  * keine Änderungen an Daten, Systemkonfigurationen oder Dateistrukturen vornimmt,\n  * typischerweise keine Auswirkungen auf andere Prozesse oder Nutzer hat.\n\n- Verwende "medium", wenn der Befehl:\n  * potenziell Änderungen an Dateien, Datenbankeinträgen oder Konfigurationen durchführt, jedoch reversibel oder mit geringer Auswirkung ist (z.B. `mv`, `cp`, `touch`, `UPDATE` mit WHERE),\n  * Netzwerkverbindungen aufbaut oder Systemprozesse anstößt (z.B. `curl`, `ping`, `systemctl restart`),\n  * selektive Datenbearbeitung in SQL betrifft, jedoch nicht strukturverändernd ist.\n\n- Verwende "high", wenn der Befehl:\n  * irreversible Änderungen am System oder an Daten verursacht (z.B. `rm -rf /`, `DROP TABLE`, `ALTER DATABASE`),\n  * kritische Dienste beeinträchtigt oder beendet (z.B. `kill -9 1`, `shutdown`),\n  * ohne weitere Rückfrage systemweite Auswirkungen haben kann,\n  * Sicherheitsrisiken birgt, z.B. durch Datenfreigabe, Prozessbeeinflussung oder das Löschen von Benutzerkonten.\n\nBeziehe immer auch Kontext und typische Folgen mit ein. Wenn Unsicherheit besteht, ist ein konservativerer (höherer) Risikowert zu bevorzugen.',
#   'format': 'json',
#   'stream': False},
#  12: {'model': 'llama3.1:8b-instruct-q5_K_M',
# ...
#   'format': 'json',
#   'stream': False},
#  996: {'model': 'llama3.1:8b-instruct-q5_K_M',
#   'prompt': 'Du bist ein spezialisierter Assistent, der natürlichsprachliche Anfragen zu CLI-Befehlen (Command Line Interface) oder SQL-Abfragen in ein strukturiertes JSON-Format übersetzt. Deine Antwort muss immer exakt im folgenden JSON-Format sein:\n\n{\n "command": "der vollständige und korrekte Befehl/die SQL-Abfrage",\n "tool": "bash/sql",\n "risk_level": "low/medium/high",\n "description": "Kurze Beschreibung des Befehls oder der Abfrage",\n "detailed_description": "Längere Erklärung, was der Befehl tut und wie die Parameter funktionieren",\n "potential_consequences": ["mögliche Auswirkungen oder Risiken des Befehls", "weitere Auswirkung wenn zutreffend"]\n}\n\nKonvertiere die folgende natürlichsprachliche Anfrage in das JSON-Format. Verwende dabei ausschließlich die Informationen aus der Anfrage und dem zugehörigen Befehl:\n\nANFRAGE: "What are the events in channel 25?"\nBEFEHL: "SELECT * FROM events WHERE event_id IN (SELECT event_id FROM channels WHERE channel_id = 25);"\n\nRichtlinien:\n1. Bestimme den Wert für "tool" korrekt basierend auf dem Befehl: Verwende "sql" für SQL-Abfragen und "bash" für Linux/Bash-Befehle.\n2. Achte unbedingt auf die korrekte Syntax des Commands. Korrigiere den Command falls nötig (z.B. fehlendes Semikolon bei SQL-Abfragen hinzufügen).\n3. Gib für SQL-Abfragen "low" als risk_level an, es sei denn, es handelt sich um DELETE, DROP, ALTER oder UPDATE-Operationen.\n4. Für CLI-Befehle bewerte das Risiko basierend auf der Möglichkeit von Datenverlust oder Systemänderungen.\n5. Die "description" sollte prägnant sein (max. 1 Satz).\n6. Die "detailed_description" sollte nicht mehr als drei Sätze umfassen.\n7. Liste unter "potential_consequences" alle relevanten möglichen Auswirkungen auf, oder ein leeres Array [], wenn keine nennenswerten Risiken bestehen.\n8. Antworte IMMER mit einem gültigen JSON-Objekt, ohne Einleitung oder Abschluss.\n9. Verwende keine Formatierungszeichen wie "\\n", "\\t" oder andere Escape-Sequenzen im JSON.\n10. Stelle sicher, dass das JSON vollständig gültig ist und direkt als Python-Dictionary geladen werden kann.\n11. Halte dich strikt an doppelte Anführungszeichen für Keys und String-Werte, wie es im JSON-Standard vorgeschrieben ist.\n12. Gib "description", "detailed_description" und "potential_consequences" IMMER in deutscher Sprache zurück, auch wenn die ursprüngliche Anfrage auf Englisch ist.\n13. Verwende bei der Übersetzung eine klare und präzise deutsche Fachsprache.\n\nErgänzende Richtlinien zur Bestimmung des "risk_level":\n\n- Verwende "low", wenn der Befehl:\n  * rein lesend ist (z.B. `ls`, `cat`, `SELECT` ohne `JOIN` auf große Tabellen),\n  * keine Änderungen an Daten, Systemkonfigurationen oder Dateistrukturen vornimmt,\n  * typischerweise keine Auswirkungen auf andere Prozesse oder Nutzer hat.\n\n- Verwende "medium", wenn der Befehl:\n  * potenziell Änderungen an Dateien, Datenbankeinträgen oder Konfigurationen durchführt, jedoch reversibel oder mit geringer Auswirkung ist (z.B. `mv`, `cp`, `touch`, `UPDATE` mit WHERE),\n  * Netzwerkverbindungen aufbaut oder Systemprozesse anstößt (z.B. `curl`, `ping`, `systemctl restart`),\n  * selektive Datenbearbeitung in SQL betrifft, jedoch nicht strukturverändernd ist.\n\n- Verwende "high", wenn der Befehl:\n  * irreversible Änderungen am System oder an Daten verursacht (z.B. `rm -rf /`, `DROP TABLE`, `ALTER DATABASE`),\n  * kritische Dienste beeinträchtigt oder beendet (z.B. `kill -9 1`, `shutdown`),\n  * ohne weitere Rückfrage systemweite Auswirkungen haben kann,\n  * Sicherheitsrisiken birgt, z.B. durch Datenfreigabe, Prozessbeeinflussung oder das Löschen von Benutzerkonten.\n\nBeziehe immer auch Kontext und typische Folgen mit ein. Wenn Unsicherheit besteht, ist ein konservativerer (höherer) Risikowert zu bevorzugen.',
#   'format': 'json',
#   'stream': False},
#  997: {'model': 'llama3.1:8b-instruct-q5_K_M',
#   'prompt': 'Du bist ein spezialisierter Assistent, der natürlichsprachliche Anfragen zu CLI-Befehlen (Command Line Interface) oder SQL-Abfragen in ein strukturiertes JSON-Format übersetzt. Deine Antwort muss immer exakt im folgenden JSON-Format sein:\n\n{\n "command": "der vollständige und korrekte Befehl/die SQL-Abfrage",\n "tool": "bash/sql",\n "risk_level": "low/medium/high",\n "description": "Kurze Beschreibung des Befehls oder der Abfrage",\n "detailed_description": "Längere Erklärung, was der Befehl tut und wie die Parameter funktionieren",\n "potential_consequences": ["mögliche Auswirkungen oder Risiken des Befehls", "weitere Auswirkung wenn zutreffend"]\n}\n\nKonvertiere die folgende natürlichsprachliche Anfrage in das JSON-Format. Verwende dabei ausschließlich die Informationen aus der Anfrage und dem zugehörigen Befehl:\n\nANFRAGE: "What are the addresses of the parties in event E66?"\nBEFEHL: "SELECT * FROM addresses WHERE address_id IN (SELECT address_id FROM parties WHERE party_id IN (SELECT party_id FROM parties_in_events WHERE event_id = 66));"\n\nRichtlinien:\n1. Bestimme den Wert für "tool" korrekt basierend auf dem Befehl: Verwende "sql" für SQL-Abfragen und "bash" für Linux/Bash-Befehle.\n2. Achte unbedingt auf die korrekte Syntax des Commands. Korrigiere den Command falls nötig (z.B. fehlendes Semikolon bei SQL-Abfragen hinzufügen).\n3. Gib für SQL-Abfragen "low" als risk_level an, es sei denn, es handelt sich um DELETE, DROP, ALTER oder UPDATE-Operationen.\n4. Für CLI-Befehle bewerte das Risiko basierend auf der Möglichkeit von Datenverlust oder Systemänderungen.\n5. Die "description" sollte prägnant sein (max. 1 Satz).\n6. Die "detailed_description" sollte nicht mehr als drei Sätze umfassen.\n7. Liste unter "potential_consequences" alle relevanten möglichen Auswirkungen auf, oder ein leeres Array [], wenn keine nennenswerten Risiken bestehen.\n8. Antworte IMMER mit einem gültigen JSON-Objekt, ohne Einleitung oder Abschluss.\n9. Verwende keine Formatierungszeichen wie "\\n", "\\t" oder andere Escape-Sequenzen im JSON.\n10. Stelle sicher, dass das JSON vollständig gültig ist und direkt als Python-Dictionary geladen werden kann.\n11. Halte dich strikt an doppelte Anführungszeichen für Keys und String-Werte, wie es im JSON-Standard vorgeschrieben ist.\n12. Gib "description", "detailed_description" und "potential_consequences" IMMER in deutscher Sprache zurück, auch wenn die ursprüngliche Anfrage auf Englisch ist.\n13. Verwende bei der Übersetzung eine klare und präzise deutsche Fachsprache.\n\nErgänzende Richtlinien zur Bestimmung des "risk_level":\n\n- Verwende "low", wenn der Befehl:\n  * rein lesend ist (z.B. `ls`, `cat`, `SELECT` ohne `JOIN` auf große Tabellen),\n  * keine Änderungen an Daten, Systemkonfigurationen oder Dateistrukturen vornimmt,\n  * typischerweise keine Auswirkungen auf andere Prozesse oder Nutzer hat.\n\n- Verwende "medium", wenn der Befehl:\n  * potenziell Änderungen an Dateien, Datenbankeinträgen oder Konfigurationen durchführt, jedoch reversibel oder mit geringer Auswirkung ist (z.B. `mv`, `cp`, `touch`, `UPDATE` mit WHERE),\n  * Netzwerkverbindungen aufbaut oder Systemprozesse anstößt (z.B. `curl`, `ping`, `systemctl restart`),\n  * selektive Datenbearbeitung in SQL betrifft, jedoch nicht strukturverändernd ist.\n\n- Verwende "high", wenn der Befehl:\n  * irreversible Änderungen am System oder an Daten verursacht (z.B. `rm -rf /`, `DROP TABLE`, `ALTER DATABASE`),\n  * kritische Dienste beeinträchtigt oder beendet (z.B. `kill -9 1`, `shutdown`),\n  * ohne weitere Rückfrage systemweite Auswirkungen haben kann,\n  * Sicherheitsrisiken birgt, z.B. durch Datenfreigabe, Prozessbeeinflussung oder das Löschen von Benutzerkonten.\n\nBeziehe immer auch Kontext und typische Folgen mit ein. Wenn Unsicherheit besteht, ist ein konservativerer (höherer) Risikowert zu bevorzugen.',
#   'format': 'json',
#   'stream': False},
#  998: {'model': 'llama3.1:8b-instruct-q5_K_M',
#   'prompt': 'Du bist ein spezialisierter Assistent, der natürlichsprachliche Anfragen zu CLI-Befehlen (Command Line Interface) oder SQL-Abfragen in ein strukturiertes JSON-Format übersetzt. Deine Antwort muss immer exakt im folgenden JSON-Format sein:\n\n{\n "command": "der vollständige und korrekte Befehl/die SQL-Abfrage",\n "tool": "bash/sql",\n "risk_level": "low/medium/high",\n "description": "Kurze Beschreibung des Befehls oder der Abfrage",\n "detailed_description": "Längere Erklärung, was der Befehl tut und wie die Parameter funktionieren",\n "potential_consequences": ["mögliche Auswirkungen oder Risiken des Befehls", "weitere Auswirkung wenn zutreffend"]\n}\n\nKonvertiere die folgende natürlichsprachliche Anfrage in das JSON-Format. Verwende dabei ausschließlich die Informationen aus der Anfrage und dem zugehörigen Befehl:\n\nANFRAGE: "What are the events in channel 26?"\nBEFEHL: "SELECT * FROM events WHERE event_id IN (SELECT event_id FROM channels WHERE channel_id = 26);"\n\nRichtlinien:\n1. Bestimme den Wert für "tool" korrekt basierend auf dem Befehl: Verwende "sql" für SQL-Abfragen und "bash" für Linux/Bash-Befehle.\n2. Achte unbedingt auf die korrekte Syntax des Commands. Korrigiere den Command falls nötig (z.B. fehlendes Semikolon bei SQL-Abfragen hinzufügen).\n3. Gib für SQL-Abfragen "low" als risk_level an, es sei denn, es handelt sich um DELETE, DROP, ALTER oder UPDATE-Operationen.\n4. Für CLI-Befehle bewerte das Risiko basierend auf der Möglichkeit von Datenverlust oder Systemänderungen.\n5. Die "description" sollte prägnant sein (max. 1 Satz).\n6. Die "detailed_description" sollte nicht mehr als drei Sätze umfassen.\n7. Liste unter "potential_consequences" alle relevanten möglichen Auswirkungen auf, oder ein leeres Array [], wenn keine nennenswerten Risiken bestehen.\n8. Antworte IMMER mit einem gültigen JSON-Objekt, ohne Einleitung oder Abschluss.\n9. Verwende keine Formatierungszeichen wie "\\n", "\\t" oder andere Escape-Sequenzen im JSON.\n10. Stelle sicher, dass das JSON vollständig gültig ist und direkt als Python-Dictionary geladen werden kann.\n11. Halte dich strikt an doppelte Anführungszeichen für Keys und String-Werte, wie es im JSON-Standard vorgeschrieben ist.\n12. Gib "description", "detailed_description" und "potential_consequences" IMMER in deutscher Sprache zurück, auch wenn die ursprüngliche Anfrage auf Englisch ist.\n13. Verwende bei der Übersetzung eine klare und präzise deutsche Fachsprache.\n\nErgänzende Richtlinien zur Bestimmung des "risk_level":\n\n- Verwende "low", wenn der Befehl:\n  * rein lesend ist (z.B. `ls`, `cat`, `SELECT` ohne `JOIN` auf große Tabellen),\n  * keine Änderungen an Daten, Systemkonfigurationen oder Dateistrukturen vornimmt,\n  * typischerweise keine Auswirkungen auf andere Prozesse oder Nutzer hat.\n\n- Verwende "medium", wenn der Befehl:\n  * potenziell Änderungen an Dateien, Datenbankeinträgen oder Konfigurationen durchführt, jedoch reversibel oder mit geringer Auswirkung ist (z.B. `mv`, `cp`, `touch`, `UPDATE` mit WHERE),\n  * Netzwerkverbindungen aufbaut oder Systemprozesse anstößt (z.B. `curl`, `ping`, `systemctl restart`),\n  * selektive Datenbearbeitung in SQL betrifft, jedoch nicht strukturverändernd ist.\n\n- Verwende "high", wenn der Befehl:\n  * irreversible Änderungen am System oder an Daten verursacht (z.B. `rm -rf /`, `DROP TABLE`, `ALTER DATABASE`),\n  * kritische Dienste beeinträchtigt oder beendet (z.B. `kill -9 1`, `shutdown`),\n  * ohne weitere Rückfrage systemweite Auswirkungen haben kann,\n  * Sicherheitsrisiken birgt, z.B. durch Datenfreigabe, Prozessbeeinflussung oder das Löschen von Benutzerkonten.\n\nBeziehe immer auch Kontext und typische Folgen mit ein. Wenn Unsicherheit besteht, ist ein konservativerer (höherer) Risikowert zu bevorzugen.',
#   'format': 'json',
#   'stream': False},
#  999: {'model': 'llama3.1:8b-instruct-q5_K_M',
#   'prompt': 'Du bist ein spezialisierter Assistent, der natürlichsprachliche Anfragen zu CLI-Befehlen (Command Line Interface) oder SQL-Abfragen in ein strukturiertes JSON-Format übersetzt. Deine Antwort muss immer exakt im folgenden JSON-Format sein:\n\n{\n "command": "der vollständige und korrekte Befehl/die SQL-Abfrage",\n "tool": "bash/sql",\n "risk_level": "low/medium/high",\n "description": "Kurze Beschreibung des Befehls oder der Abfrage",\n "detailed_description": "Längere Erklärung, was der Befehl tut und wie die Parameter funktionieren",\n "potential_consequences": ["mögliche Auswirkungen oder Risiken des Befehls", "weitere Auswirkung wenn zutreffend"]\n}\n\nKonvertiere die folgende natürlichsprachliche Anfrage in das JSON-Format. Verwende dabei ausschließlich die Informationen aus der Anfrage und dem zugehörigen Befehl:\n\nANFRAGE: "What are the addresses of the parties in event E68?"\nBEFEHL: "SELECT * FROM addresses WHERE address_id IN (SELECT address_id FROM parties WHERE party_id IN (SELECT party_id FROM parties_in_events WHERE event_id = 68));"\n\nRichtlinien:\n1. Bestimme den Wert für "tool" korrekt basierend auf dem Befehl: Verwende "sql" für SQL-Abfragen und "bash" für Linux/Bash-Befehle.\n2. Achte unbedingt auf die korrekte Syntax des Commands. Korrigiere den Command falls nötig (z.B. fehlendes Semikolon bei SQL-Abfragen hinzufügen).\n3. Gib für SQL-Abfragen "low" als risk_level an, es sei denn, es handelt sich um DELETE, DROP, ALTER oder UPDATE-Operationen.\n4. Für CLI-Befehle bewerte das Risiko basierend auf der Möglichkeit von Datenverlust oder Systemänderungen.\n5. Die "description" sollte prägnant sein (max. 1 Satz).\n6. Die "detailed_description" sollte nicht mehr als drei Sätze umfassen.\n7. Liste unter "potential_consequences" alle relevanten möglichen Auswirkungen auf, oder ein leeres Array [], wenn keine nennenswerten Risiken bestehen.\n8. Antworte IMMER mit einem gültigen JSON-Objekt, ohne Einleitung oder Abschluss.\n9. Verwende keine Formatierungszeichen wie "\\n", "\\t" oder andere Escape-Sequenzen im JSON.\n10. Stelle sicher, dass das JSON vollständig gültig ist und direkt als Python-Dictionary geladen werden kann.\n11. Halte dich strikt an doppelte Anführungszeichen für Keys und String-Werte, wie es im JSON-Standard vorgeschrieben ist.\n12. Gib "description", "detailed_description" und "potential_consequences" IMMER in deutscher Sprache zurück, auch wenn die ursprüngliche Anfrage auf Englisch ist.\n13. Verwende bei der Übersetzung eine klare und präzise deutsche Fachsprache.\n\nErgänzende Richtlinien zur Bestimmung des "risk_level":\n\n- Verwende "low", wenn der Befehl:\n  * rein lesend ist (z.B. `ls`, `cat`, `SELECT` ohne `JOIN` auf große Tabellen),\n  * keine Änderungen an Daten, Systemkonfigurationen oder Dateistrukturen vornimmt,\n  * typischerweise keine Auswirkungen auf andere Prozesse oder Nutzer hat.\n\n- Verwende "medium", wenn der Befehl:\n  * potenziell Änderungen an Dateien, Datenbankeinträgen oder Konfigurationen durchführt, jedoch reversibel oder mit geringer Auswirkung ist (z.B. `mv`, `cp`, `touch`, `UPDATE` mit WHERE),\n  * Netzwerkverbindungen aufbaut oder Systemprozesse anstößt (z.B. `curl`, `ping`, `systemctl restart`),\n  * selektive Datenbearbeitung in SQL betrifft, jedoch nicht strukturverändernd ist.\n\n- Verwende "high", wenn der Befehl:\n  * irreversible Änderungen am System oder an Daten verursacht (z.B. `rm -rf /`, `DROP TABLE`, `ALTER DATABASE`),\n  * kritische Dienste beeinträchtigt oder beendet (z.B. `kill -9 1`, `shutdown`),\n  * ohne weitere Rückfrage systemweite Auswirkungen haben kann,\n  * Sicherheitsrisiken birgt, z.B. durch Datenfreigabe, Prozessbeeinflussung oder das Löschen von Benutzerkonten.\n\nBeziehe immer auch Kontext und typische Folgen mit ein. Wenn Unsicherheit besteht, ist ein konservativerer (höherer) Risikowert zu bevorzugen.',
#   'format': 'json',
#   'stream': False}}

# %% [markdown]
# # Synthetische Trainingsdaten mit Llama

# %%
dataset_df
# Out:
#                                                 nl_prompt  \
# 0       What is the total number of addresses for each...
# 1       Find all addresses in the United States that d...
# 2       What is the count of addresses in Europe by ci...
# 3       Get a list of all countries, along with the nu...
# 4       What is the total number of addresses for each...
# ...                                                   ...
# 174974                          List all running services
# 174975  Find and replace 'foo' with 'bar' in all .txt ...
# 174976                       Check if port 8080 is in use
# 174977                   Display real-time disk I/O stats
# 174978         Create a compressed archive of a directory
#
#                                                   command  check  \
# 0       SELECT country, state_province_county, COUNT(*...   True
# 1       SELECT * FROM addresses WHERE country = 'Unite...   True
# 2       SELECT city, COUNT(*) AS address_count FROM ad...   True
# 3       SELECT country, COUNT(*) AS address_count FROM...   True
# 4       SELECT city, COUNT(*) AS total_addresses FROM ...   True
# ...                                                   ...    ...
# 174974                systemctl list-units --type=service   True
# 174975                         sed -i 's/foo/bar/g' *.txt   True
# 174976                         netstat -tulnp | grep 8080   True
# 174977                                       iostat -dx 1   True
# 174978         tar -czvf backup.tar.gz /path/to/directory   True
#
#         __index_level_0__      id json
# 0                       0       1
# 1                       1       2
# 2                       2       3
# 3                       3       4
# 4                       4       5
# ...                   ...     ...  ...
# 174974              25418  174975
# 174975              25419  174976
# 174976              25420  174977
# 174977              25421  174978
# 174978              25422  174979
#
# [174979 rows x 6 columns]

# %%
errors = {}
for id, batch in tqdm(requests.items(), desc="Befrage Ollama", unit="Anfrage"):
    results = {}
    print(id)
    for index, req in batch.items():
        try:
            response = r.post("http://localhost:11434/api/generate", json=req)
            response.raise_for_status()
            result = response.json()
            results[index] = result.get("response")


        except Exception as e:
            errors[index] = str(e)
    with open(f"../data/json_results/results_{id}.json", "w") as f:
        json.dump(results, f)

print(len(errors))
# Out:
# Befrage Ollama:   0%|          | 0/3 [00:00<?, ?Anfrage/s]
# batch_173
# Befrage Ollama:   0%|          | 0/3 [1:10:19<?, ?Anfrage/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 8
#       6 for index, req in batch.items():
#       7     try:
# ----> 8         response = r.post("http://localhost:11434/api/generate", json=req)
#       9         response.raise_for_status()
#      10         result = response.json()
#
# File ~/PycharmProjects/thesis_playground/.venv/lib/python3.12/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/PycharmProjects/thesis_playground/.venv/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/PycharmProjects/thesis_playground/.venv/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/PycharmProjects/thesis_playground/.venv/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/PycharmProjects/thesis_playground/.venv/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/PycharmProjects/thesis_playground/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/PycharmProjects/thesis_playground/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/PycharmProjects/thesis_playground/.venv/lib/python3.12/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /usr/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /usr/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /usr/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
results
# Out:
# {0: '{\n "command": "SELECT country, state_province_county, COUNT(*) AS total_addresses FROM addresses GROUP BY country, state_province_county;",\n "tool": "sql",\n "risk_level": "low",\n "description": "Ermittelt die Gesamtzahl der Adressen für jedes Land, gruppiert nach Bundesland/Kreis.",\n "detailed_description": "Diese SQL-Abfrage zählt die Anzahl der Adressen in einer Tabelle und gruppiert das Ergebnis nach Ländern und deren Unterteilungen. Sie dient zur Informationsbeschaffung und verändert keine Daten. Die Abfrage ist somit rein lesend und birgt daher kein Risiko für Datenverlust oder -manipulation.",\n "potential_consequences": []\n}',
#  1: '{\n "command": "SELECT * FROM addresses WHERE country = \'United States\' AND state_province_county IS NULL;",\n "tool": "sql",\n "risk_level": "low",\n "description": "Findet alle Adressen in den Vereinigten Staaten, bei denen kein Bundesstaat oder Landkreis angegeben ist.",\n "detailed_description": "Diese SQL-Abfrage durchsucht eine Tabelle namens \'addresses\' nach Einträgen, bei denen das Land \'United States\' ist und die Spalte \'state_province_county\' leer (NULL) ist. Die Abfrage gibt alle passenden Zeilen zurück, ohne Änderungen an der Datenbank vorzunehmen. Diese Art von Abfrage kann für Analysen oder zur Identifizierung fehlender Informationen in einer Datenbank verwendet werden.",\n "potential_consequences": []\n}',
#  2: '{\n "command": "SELECT city, COUNT(*) AS address_count FROM addresses WHERE country = \'Europe\' GROUP BY city ORDER BY address_count DESC;",\n "tool": "sql",\n "risk_level": "low",\n "description": "Zählt die Anzahl der Adressen in Europa nach Stadt und sortiert diese absteigend.",\n "detailed_description": "Diese SQL-Abfrage gruppiert die Adressen nach Stadt und zählt die Anzahl der Adressen pro Stadt. Die Ergebnisse werden dann in absteigender Reihenfolge nach der Anzahl der Adressen sortiert. Dieser Befehl führt lediglich einen Lesevorgang durch und ändert keine Daten.",\n "potential_consequences": []\n}',
#  3: '{\n "command": "SELECT country, COUNT(*) AS address_count FROM addresses GROUP BY country;",\n "tool": "sql",\n "risk_level": "low",\n "description": "Die Anfrage liefert eine Liste aller Länder mit der Anzahl der Adressen in jedem Land.",\n "detailed_description": "Diese SQL-Abfrage gruppiert die Daten aus der Tabelle \'addresses\' nach dem Feld \'country\' und zählt für jedes Land die Anzahl der Einträge. Die Ergebnisse werden in zwei Spalten angezeigt: \'country\' für den Ländernamen und \'address_count\' für die Anzahl der Adressen. Diese Abfrage ist rein lesend und verändert keine Daten.",\n "potential_consequences": []\n}',
#  4: '{\n "command": "SELECT city, COUNT(*) AS total_addresses FROM addresses WHERE country = \'Japan\' GROUP BY city;",\n "tool": "sql",\n "risk_level": "low",\n "description": "Ermittelt die Gesamtzahl der Adressen für jede Stadt in Japan.",\n "detailed_description": "Diese SQL-Abfrage gruppiert die Adressen nach Städten und zählt die Anzahl der Adressen pro Stadt. Die Abfrage filtert dabei nur Adressen aus Japan. Es handelt sich um eine rein lesende Abfrage ohne Auswirkungen auf die Datenbank.",\n "potential_consequences": []\n}',
#  5: '{\n "command": "SELECT other_address_details FROM addresses WHERE address_id=10;",\n "tool": "sql",\n "risk_level": "low",\n "description": "Abrufen einer Liste von Adresszeilen für eine bestimmte Adresse mit der ID 10.",\n "detailed_description": "Diese SQL-Abfrage dient dazu, spezifische Details zu einer Adresse aus der Datenbank abzurufen. Sie verwendet die WHERE-Klausel, um die Ergebnisse auf die Adresse mit der ID 10 einzuschränken. Die Abfrage ist lesend und verändert keine Daten.",\n "potential_consequences": []\n}',
#  6: '{\n "command": "SELECT line_2, COUNT(*) AS total_addresses FROM addresses GROUP BY line_2;",\n "tool": "sql",\n "risk_level": "low",\n "description": "Ermittelt die Gesamtzahl der Adressen für jedes Attribut in der line_2-Spalte.",\n "detailed_description": "Diese SQL-Abfrage gruppiert die Einträge in der addresses-Tabelle nach dem line_2-Attribut und zählt die Anzahl der Adressen pro Gruppe. Die Ergebnisse liefern Informationen über die Verteilung der Adressen innerhalb der Tabelle. Da es sich um eine reine Leseoperation handelt, verändert sie keine Daten.",\n "potential_consequences": []\n}',
#  7: '{\n "command": "SELECT * FROM addresses WHERE country IN (\'Australia\', \'China\', \'Japan\', \'South Korea\', \'Taiwan\') AND state_province_county IS NOT NULL ORDER BY country, line_1;",\n "tool": "sql",\n "risk_level": "low",\n "description": "Findet alle Adressen in Ländern des asiatisch-pazifischen Raums, die einen Bundesstaat/Provinz/Grafschaft haben und sortiert sie nach Land und Straße.",\n "detailed_description": "Diese SQL-Abfrage durchsucht eine Tabelle namens \'addresses\' nach Einträgen, die bestimmte Länder im asiatisch-pazifischen Raum enthalten und einen nicht-leeren Wert für den Bundesstaat/Provinz/Grafschaft haben. Die Ergebnisse werden dann nach dem Land und der Straße sortiert. Dieser Vorgang ist rein lesend und ändert keine Daten.",\n "potential_consequences": []\n}',
#  8: '{\n "command": "SELECT DISTINCT city FROM addresses WHERE country = \'France\';",\n "tool": "sql",\n "risk_level": "low",\n "description": "Liest eine Liste aller Städte in Frankreich aus einer Datenbank.",\n "detailed_description": "Diese SQL-Abfrage selektiert eindeutige Stadtnamen aus einer Tabelle namens addresses, bei denen das Land \'Frankreich\' ist. Die Abfrage gibt keine Informationen über die Struktur der Tabelle preis und führt keine Änderungen an den Daten durch. Sie dient lediglich dazu, bestimmte Informationen zu lesen.",\n "potential_consequences": []\n}',
#  9: '{\n "command": "SELECT city, COUNT(*) AS total_addresses FROM addresses WHERE country = \'United States\' GROUP BY city;",\n "tool": "sql",\n "risk_level": "low",\n "description": "Ermittelt die Gesamtzahl der Adressen in jedem Stadtgebiet der Vereinigten Staaten.",\n "detailed_description": "Diese SQL-Abfrage gruppiert die Datenbank \'addresses\' nach der Spalte \'city\' und zählt die Anzahl der Einträge für jede Stadt, bei denen das Land \'United States\' ist. Die Ergebnisse liefern somit eine Übersicht über die Verteilung der Adressen in den verschiedenen Städten. Durch die Verwendung von SELECT ohne Modifikationsanweisungen wie UPDATE oder DELETE bleibt diese Abfrage lesend und verändert keine Daten.",\n "potential_consequences": []\n}'}

# %% [markdown]
# Kombiniere die Resultate und ergänze sie mit dem Dataframe
